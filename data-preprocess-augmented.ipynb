# %% [markdown]
# ## Data Augmentation for Imbalance
#
# ### Purpose of This Jupyter Notebook
# - This notebook focuses on implementing data `augmentation techniques` to address the issue of `class imbalance` in the current dataset.
# - Furthermore, we apply basic NLP preprocess for teh text data inputs.
#
# ### Why Is Data Augmentation Necessary for Imbalanced Datasets?
# - `Enhancing Minority Class Representation`:
#     - Imbalanced datasets often have a disproportionately low number of samples in one or more classes. Data augmentation techniques, such as oversampling, `generate synthetic examples` (**in our case this strategy implemented**) to balance the dataset, improving the model's ability to learn features from the minority class.
# - `Preventing Overfitting`:
#     - Training a model on an imbalanced dataset often leads to overfitting, where the model heavily favors the majority class. By introducing diverse synthetic samples, data augmentation encourages the model to generalize better across all classes.

# %% [markdown]
# ## Setting the Scene
# - For the scope of this assignment, we will utilize the following Python libraries to accomplish data augmentation.
#
# ### Core Libraries
# - **`pandas`**: A fast, powerful, flexible, and easy-to-use open-source data analysis and manipulation tool built on top of the Python programming language.[Documentation Pandas](https://pandas.pydata.org)
# - **`numpy`**: A fundamental package for scientific computing in Python. It provides support for arrays, mathematical functions, linear algebra, and more.  [Documentation Counter](https://docs.python.org/3/library/collections.html#collections.Counter)
# - **`typing.Counter`**: A collection for counting hashable objects. [Documentation Counter](https://docs.python.org/3/library/collections.html#collections.Counter)
# - **`matplotlib.pyplot`**: A comprehensive library for creating static, animated, and interactive visualizations in Python.[Documentation Matplotlib](https://matplotlib.org)
# - **`seaborn`**: Built on top of Matplotlib, Seaborn provides a high-level interface for creating visually appealing and informative statistical graphics. It simplifies the creation of complex plots such as heatmaps, violin plots, and pair plots, and supports themes for consistent styling. [Documentation Seeaborn](https://seaborn.pydata.org/)
# - **`random`**: A Python module that provides tools for generating random numbers, shuffling data, and sampling elements. It supports generating pseudo-random numbers for various distributions, making it useful for simulations, data augmentation, and randomized algorithms. [Documentation Random](https://docs.python.org/3/library/random.html)
# - **`nltk`**: The Natural Language Toolkit (NLTK) is a powerful library for processing and analyzing human language data. It includes tools for tokenization, stemming, lemmatization, parsing, and more, enabling a wide range of tasks such as text classification, sentiment analysis, and machine translation. [Documentation NLTK](https://www.nltk.org/)
# - **`subprocess`**: A module for running and managing external processes directly from Python. It allows interaction with command-line tools and scripts, supporting input/output redirection, process piping, and advanced subprocess management. [Documentation Subprocess](https://docs.python.org/3/library/subprocess.html)
# - **`re`**: The regular expression library in Python, used for pattern matching and text manipulation. It supports a wide range of string operations, such as searching, splitting, and replacing text based on patterns. Ideal for tasks involving text parsing and extraction. [Documentation Re](https://docs.python.org/3/library/re.html)

# %%
# !pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/evangelia/Downloads/practical-2/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Load python libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from typing import Counter
import seaborn as sns
import os
import random
import re
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from collections import Counter
import subprocess
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
import string
# Out:
# [nltk_data] Downloading package punkt to /Users/evangelia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/evangelia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/evangelia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Load Data

# %%
# define as global variable the folder named "data"
# Create a directory named 'data' if it doesn't exist
os.makedirs('data', exist_ok=True)
# Download the CSV file into the 'data' folder
# !wget -O data/incidents_train.csv https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/main/data/incidents_train.csv
# Load the dataset from the 'data' folder
data = pd.read_csv('data/incidents_train.csv', index_col=0)
# Out:
# --2024-11-22 05:03:29--  https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/main/data/incidents_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8003::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12866710 (12M) [text/plain]
# Saving to: ‘data/incidents_train.csv’
#
# data/incidents_trai 100%[===================>]  12,27M  3,35MB/s    in 3,7s
#
# 2024-11-22 05:03:33 (3,29 MB/s) - ‘data/incidents_train.csv’ saved [12866710/12866710]

# %%
print(len(data)) # preview shape
# Out:
# 5082

# %%
data.head() # preview data
# Out:
#    year  month  day country                             title  \
# 0  1994      1    7      us  Recall Notification: FSIS-024-94
# 1  1994      3   10      us  Recall Notification: FSIS-033-94
# 2  1994      3   28      us  Recall Notification: FSIS-014-94
# 3  1994      4    3      us  Recall Notification: FSIS-009-94
# 4  1994      7    1      us  Recall Notification: FSIS-001-94
#
#                                                 text hazard-category  \
# 0  Case Number: 024-94   \n            Date Opene...      biological
# 1  Case Number: 033-94   \n            Date Opene...      biological
# 2  Case Number: 014-94   \n            Date Opene...      biological
# 3  Case Number: 009-94   \n            Date Opene...  foreign bodies
# 4  Case Number: 001-94   \n            Date Opene...  foreign bodies
#
#                product-category                  hazard  \
# 0  meat, egg and dairy products  listeria monocytogenes
# 1  meat, egg and dairy products            listeria spp
# 2  meat, egg and dairy products  listeria monocytogenes
# 3  meat, egg and dairy products        plastic fragment
# 4  meat, egg and dairy products        plastic fragment
#
#                        product
# 0               smoked sausage
# 1                      sausage
# 2                   ham slices
# 3  thermal processed pork meat
# 4               chicken breast

# %%
data.keys() # preview columns
# Out:
# Index(['year', 'month', 'day', 'country', 'title', 'text', 'hazard-category',
#        'product-category', 'hazard', 'product'],
#       dtype='object')

# %% [markdown]
# - Before applying data aygmentation, we will firstly `investigate the imbalance` of the columns being our labels that is (`hazard`,`product`, `hazard-category`, `hazard-product`).

# %%
def print_column(incidents: pd.DataFrame, column: str, num_examples: int = 10):
    """
    Analyzes and visualizes the distribution of unique values in a specified column of a pandas DataFrame.

    :param incidents: pd.DataFrame
        The input DataFrame containing the data to be analyzed.
    :param column: str
        The column name in the DataFrame to analyze and visualize.
    :param num_examples: int, optional (default=10)
        The number of top unique values and their counts to display in the console.
    
    :return: None
        The function outputs a bar chart and prints the top unique values to the console.
    """
    # Attempt to extract all unique values in the column.
    # If column values are lists or arrays, flatten them before finding unique values.
    try:
        values = np.unique(np.concatenate(incidents[column].values))
    except ValueError:
        values = np.unique(incidents[column].values)
    
    # Count the occurrences of each unique value in the column.
    counts = np.array([sum([v in label for label in incidents[column].values]) for v in values])
    
    # Sort values by their frequency in descending order.
    idx = np.argsort(counts)[::-1]
    values = values[idx]
    counts = counts[idx]

    # Plot a bar chart of the unique value counts.
    num_values = len(counts)
    plt.bar(range(num_values), counts)

    # Adjust x-axis labels for readability.
    if num_values <= 25:
        plt.xticks(range(num_values), values, rotation=90)
    else:
        plt.xticks([], [], rotation=90)
    
    # Print the column name and the total number of unique values.
    print(f'Column "{column}" (n = {len(values):d}):\n')

    # Print the top `num_examples` unique values and their counts.
    for v, n in zip(values[:num_examples], counts[:num_examples]):
        print(f'  {v}:{" "*(50-len(v))}{n:5d}')

# %%
print_column(data, 'hazard-category')
# Out:
# Column "hazard-category" (n = 10):
#
#   allergens:                                          1854
#   biological:                                         1741
#   foreign bodies:                                      561
#   fraud:                                               371
#   chemical:                                            287
#   other hazard:                                        134
#   packaging defect:                                     54
#   organoleptic aspects:                                 53
#   food additives and flavourings:                       24
#   migration:                                             3

# %% [markdown]
# - It is clear that the `hazard-category` column exhibits an `imbalance` in the distribution of its values.
#     - For example, `allergens` has a frequence equal to `1854`, whereas `migration` has  a frequence equal to `3`.
# - We will move on with the column `hazard`.

# %%
print_column(data, 'hazard',128)
# Out:
# Column "hazard" (n = 128):
#
#   listeria monocytogenes:                              665
#   salmonella:                                          621
#   milk and products thereof:                           588
#   nuts:                                                240
#   escherichia coli:                                    237
#   cereals:                                             214
#   peanuts and products thereof:                        211
#   eggs and products thereof:                           208
#   cereals containing gluten and products thereof:      207
#   plastic fragment:                                    206
#   other:                                               185
#   soybeans and products thereof:                       170
#   metal fragment:                                      155
#   sulphur dioxide:                                     111
#   inspection issues:                                   101
#   sulphur dioxide and sulphites:                        93
#   glass fragment:                                       86
#   other not classified:                                 80
#   almond:                                               66
#   misdescription:                                       59
#   unauthorised substance ethylene oxide:                51
#   chemical:                                             49
#   mustard and products thereof:                         48
#   toxin:                                                40
#   processing:                                           39
#   clostridium botulinum:                                39
#   sesame seeds and products thereof:                    39
#   fish and products thereof:                            39
#   incorrect labeling:                                   38
#   labelling/misdescription:                             37
#   foreign bodies:                                       36
#   virus:                                                34
#   walnut:                                               32
#   spoilage:                                             30
#   heavy metals:                                         30
#   cashew:                                               29
#   rubber fragments:                                     28
#   moulds:                                               28
#   incorrect use by dates:                               23
#   insects:                                              22
#   other not classified chemical hazards:                22
#   packaging defect:                                     22
#   bulging packaging:                                    21
#   norovirus:                                            20
#   insufficient labelling/documentation:                 19
#   crustaceans and products thereof:                     17
#   pecan nut:                                            17
#   microbiological contamination:                        17
#   hazelnut:                                             16
#   undeclared additive:                                  16
#   misbranding:                                          16
#   bacillus spp.:                                        14
#   allergens:                                            13
#   improper conditions:                                  13
#   other not classified biological hazards:              13
#   poor or insufficient controls:                        12
#   e 425 - konjac unauthorised:                          12
#   bone fragment:                                        12
#   chemical compound (unauthorised):                     11
#   enteroviruses:                                        10
#   cyclospora:                                           10
#   Aflatoxin:                                            10
#   patulin:                                              10
#   specified risk material (srm):                         9
#   staphylococcus:                                        9
#   high content of cyanide:                               9
#   sulphates/sulphites:                                   9
#   other not classified hazards for foreign bodies:       8
#   pistachio nut:                                         8
#   chemical compound (high content):                      8
#   celery and products thereof:                           7
#   stones:                                                7
#   damaged packaging:                                     7
#   cronobacter spp:                                       7
#   unauthorised import:                                   7
#   undeclared constituent:                                7
#   too high content of tetrahydrocannabinol (THC):        7
#   antibiotics, vet drugs:                                7
#   coliforms:                                             7
#   pathogenic bacteria:                                   7
#   taste disturbance:                                     6
#   chlorine:                                              6
#   bad smell / off odor:                                  6
#   unauthorised placing on the market:                    6
#   poor hygienic state:                                   6
#   listeria spp:                                          5
#   mislabelled:                                           5
#   pseudomonas spp.:                                      5
#   brazil nut:                                            4
#   abnormal smell:                                        4
#   yeasts:                                                4
#   molluscs and products thereof:                         4
#   non compliance with HACCP:                             4
#   pieces of wood:                                        4
#   pahs:                                                  4
#   unauthorised colour sudan 4:                           4
#   product category/characteristics:                      4
#   unauthorised substance sildenafil:                     4
#   novel food:                                            4
#   polycyclic aromatic hydrocarbons:                      4
#   improper packaging:                                    4
#   high content of vitamins:                              4
#   unfit for human consumption:                           3
#   alkaloids:                                             3
#   amygdalin:                                             3
#   unauthorised operator:                                 3
#   alcohol content:                                       3
#   too high content of fluorinated organic chemicals:     3
#   tampering:                                             3
#   sulfamethazine unauthorised:                           3
#   staphylococcal enterotoxin:                            3
#   vibrio spp:                                            3
#   altered organoleptic characteristics:                  3
#   false marketing claims:                                3
#   phenylpyrazole:                                        3
#   haloxyfop:                                             3
#   other not classified allergen hazards:                 3
#   other misbranding issues:                              3
#   organochlorine:                                        3
#   coconut:                                               3
#   ochratoxin:                                            3
#   compositional deviation:                               3
#   contaminant:                                           3
#   nitrogen:                                              3
#   dairy products:                                        3
#   dioxins:                                               3
#   high content of copper:                                3
#   paralytic shellfish poisoning (psp) toxins:            3

# %% [markdown]
# - It is clear that the `hazard` column exhibits an `imbalance` in the distribution of its values.
#     - The `hazard` column demonstrates `a long right skew`, indicating that `a small number of categories dominate the dataset`, while most other categories occur infrequently. This imbalance highlights the need for targeted data augmentation or resampling techniques to ensure the model adequately learns from underrepresented classes.
# - We will move on with the column `product-category`.

# %%
print_column(data, 'product-category',22)
# Out:
# Column "product-category" (n = 22):
#
#   meat, egg and dairy products:                       1434
#   cereals and bakery products:                         671
#   fruits and vegetables:                               535
#   prepared dishes and snacks:                          469
#   seafood:                                             268
#   soups, broths, sauces and condiments:                264
#   nuts, nut products and seeds:                        262
#   ices and desserts:                                   222
#   cocoa and cocoa preparations, coffee and tea:        210
#   alcoholic beverages:                                 193
#   confectionery:                                       170
#   non-alcoholic beverages:                             134
#   dietetic foods, food supplements, fortified foods:   131
#   herbs and spices:                                    125
#   other food product / mixed:                           55
#   pet feed:                                             20
#   fats and oils:                                        19
#   food additives and flavourings:                        8
#   honey and royal jelly:                                 8
#   food contact materials:                                7
#   feed materials:                                        6
#   sugars and syrups:                                     5

# %% [markdown]
# - It is clear that the `product-category` column exhibits an `imbalance` in the distribution of its values.
#     - For example, `meet,egg and dairy products` has a frequence equal to `1434`, whereas `sugars and syrups` has  a frequence equal to `5`.
# - We will move on with the column `product`.

# %%
print_column(data, 'product',1022)
# Out:
# Column "product" (n = 1022):
#
#   chicken:                                             309
#   beef:                                                280
#   cheese:                                              231
#   chocolate:                                           206
#   ice cream:                                           185
#   nuts:                                                160
#   chicken based products:                              138
#   milk:                                                131
#   sauce:                                               124
#   cakes:                                               116
#   sausage:                                             108
#   beef meat:                                           107
#   ready to eat - cook meals:                            79
#   cookies:                                              78
#   salads:                                               74
#   pork meat:                                            72
#   bars:                                                 67
#   bread:                                                60
#   soup:                                                 58
#   ground beef:                                          58
#   chocolates:                                           54
#   ham:                                                  52
#   peanuts:                                              51
#   salmon:                                               50
#   biscuits:                                             49
#   rice:                                                 47
#   cereal:                                               47
#   thermal processed pork meat:                          43
#   pasta:                                                43
#   sandwiches:                                           42
#   mushrooms:                                            41
#   noodle:                                               41
#   eggs:                                                 39
#   crackers:                                             36
#   other not classified meat products:                   35
#   beef products:                                        35
#   pistachio nuts:                                       34
#   Fishes not identified:                                34
#   turkey:                                               34
#   chocolate bars:                                       33
#   pastry:                                               33
#   chocolate products:                                   33
#   prepared dish:                                        32
#   candies:                                              32
#   corn:                                                 31
#   yoghurt:                                              30
#   dark chocolates:                                      30
#   flour:                                                30
#   frozen beef:                                          29
#   sesame:                                               29
#   vegetables:                                           28
#   pizza:                                                28
#   noodles:                                              27
#   chicken breast:                                       27
#   pork sausage:                                         27
#   beer:                                                 26
#   potato chips:                                         26
#   food supplement:                                      26
#   chicken preparations:                                 26
#   tahini:                                               26
#   sunflower seed:                                       26
#   onions:                                               26
#   sauces:                                               26
#   dried beef meat:                                      25
#   spread:                                               25
#   rolls:                                                25
#   desserts:                                             25
#   pesto:                                                25
#   coconuts:                                             25
#   jellies:                                              25
#   raw beef meat:                                        24
#   sprouts:                                              23
#   other dairy products:                                 23
#   poultry:                                              23
#   turkey and turkey preparations:                       23
#   chilli:                                               23
#   dietary supplement:                                   23
#   raisins:                                              23
#   fresh mushrooms:                                      23
#   cereals:                                              22
#   salami:                                               21
#   baby food:                                            21
#   seasoning:                                            21
#   bakery products:                                      21
#   pastry products:                                      21
#   dumplings:                                            21
#   thermal processed beef meat:                          20
#   pet feed:                                             20
#   peas:                                                 20
#   precooked cooked beef meat products:                  20
#   almonds:                                              19
#   beverage:                                             19
#   other types of meat:                                  19
#   protein bar:                                          19
#   basil:                                                18
#   tea:                                                  18
#   shrimps:                                              18
#   curry:                                                18
#   oysters:                                              17
#   snack mix:                                            17
#   breakfast cereals:                                    17
#   cooked chicken:                                       17
#   broccoli:                                             17
#   beans:                                                17
#   prepared dishes:                                      16
#   snacks (various):                                     16
#   blue cheese:                                          15
#   apricots:                                             15
#   wraps:                                                15
#   spring rolls:                                         15
#   tuna:                                                 15
#   dressing:                                             14
#   spinach:                                              14
#   dried apricots:                                       14
#   fish products:                                        14
#   pig meat - pork:                                      14
#   raw milk:                                             14
#   milk chocolates:                                      14
#   pork preparation:                                     14
#   prepared salads:                                      13
#   infant formula:                                       13
#   cereal bars:                                          13
#   frozen beef patties:                                  13
#   muesli:                                               13
#   chorizo:                                              13
#   pancakes:                                             13
#   confectionery:                                        13
#   dates:                                                13
#   jam:                                                  13
#   wine:                                                 12
#   buns:                                                 12
#   basil pesto sauce:                                    12
#   lasagne:                                              12
#   muffins:                                              12
#   pasta products:                                       12
#   potatoes:                                             12
#   frozen pizza:                                         12
#   protein powder:                                       12
#   apricot kernels:                                      12
#   dip-sauce:                                            11
#   rice crackers:                                        11
#   Not classified pork meat:                             11
#   sausage products:                                     11
#   seafood:                                              11
#   chocolate eggs:                                       11
#   cheddar cheese:                                       11
#   Catfishes (freshwater):                               11
#   veal:                                                 11
#   tortilla:                                             11
#   coconut juice:                                        10
#   chickpeas:                                            10
#   apple juice:                                          10
#   cow milk cheese:                                      10
#   granola:                                              10
#   sesame seeds:                                         10
#   tofu:                                                 10
#   alfalfa sprouts:                                      10
#   noodle soup:                                          10
#   coconut milk:                                         10
#   sesame paste:                                         10
#   prawns:                                               10
#   macadamia nuts:                                       10
#   pâté:                                                 10
#   prepared dishes and snacks:                           10
#   bread and products therefor:                           9
#   pasta salad:                                           9
#   baby spinach:                                          9
#   mashed chickpeas (hummus):                             9
#   milk chocolate covered raisins:                        9
#   smoked sausage:                                        9
#   herring:                                               9
#   soft cheese:                                           9
#   Precooked cooked pork meat products:                   9
#   potato salad:                                          9
#   bottled water:                                         9
#   mitragyna speciosa (kratom):                           9
#   kale:                                                  8
#   spice mix:                                             8
#   walnuts:                                               8
#   coriander:                                             8
#   feta cheese:                                           8
#   rice snack:                                            8
#   fruit juice:                                           8
#   chicken products - frozen:                             8
#   halloumi cheese:                                       8
#   butter:                                                8
#   cashew:                                                8
#   plums:                                                 8
#   peppers:                                               8
#   apples:                                                8
#   cider:                                                 8
#   honey:                                                 8
#   raspberries:                                           8
#   almond products:                                       8
#   sliced ham:                                            8
#   protein bars:                                          7
#   brazil nuts:                                           7
#   minced pork:                                           7
#   dried mushrooms:                                       7
#   dried plums:                                           7
#   fruit mix:                                             7
#   cheese spread:                                         7
#   wafers:                                                7
#   frozen vegetables:                                     7
#   instant noodles:                                       7
#   chia seeds:                                            7
#   clams:                                                 7
#   mustard:                                               7
#   sultanas:                                              7
#   chilli sauce:                                          7
#   grated coconut:                                        7
#   meat and meat products (other than poultry):           7
#   fresh vegetables:                                      7
#   whey protein:                                          7
#   coffee beans:                                          7
#   frozen peas:                                           7
#   chilled chicken:                                       7
#   tortilla chips:                                        7
#   frozen poultry:                                        7
#   sugar:                                                 7
#   alcoholic beverages:                                   7
#   mayonnaise:                                            7
#   cod:                                                   6
#   chocolate chips:                                       6
#   pasteurized milk:                                      6
#   radish:                                                6
#   peaches:                                               6
#   plastics:                                              6
#   frozen pork preparations:                              6
#   pudding:                                               6
#   hot dogs:                                              6
#   dark chocolate coated almonds:                         6
#   oats:                                                  6
#   crisps:                                                6
#   palm oil:                                              6
#   cheese products:                                       6
#   frozen chicken:                                        6
#   olives:                                                6
#   cupcakes:                                              6
#   sport drink:                                           6
#   chicken noodle soup:                                   6
#   crabs:                                                 6
#   poultry meat:                                          6
#   cream cheese:                                          6
#   chilled salads:                                        6
#   golden raisins/sultanas:                               6
#   tomato sauce:                                          6
#   lamb:                                                  6
#   brie cheese:                                           6
#   baking mix:                                            6
#   waffles:                                               6
#   fruits and vegetables:                                 6
#   mineral water:                                         6
#   beef trimmings:                                        6
#   frozen beef products:                                  6
#   mozzarella:                                            6
#   duck:                                                  6
#   milk drink:                                            6
#   minced beef:                                           6
#   fresh pork:                                            6
#   algae:                                                 6
#   Veggie Burger:                                         6
#   salt:                                                  6
#   lettuce:                                               6
#   green pesto:                                           5
#   milk powder:                                           5
#   cauliflower:                                           5
#   feed materials:                                        5
#   chicken pie:                                           5
#   chilli powder:                                         5
#   barbecue sauce:                                        5
#   millet:                                                5
#   poppy:                                                 5
#   semi-soft cheese:                                      5
#   parsley:                                               5
#   fish roe:                                              5
#   ginger powder:                                         5
#   fresh processed beef meat products:                    5
#   angus beef:                                            5
#   goat cheese:                                           5
#   goat milk:                                             5
#   mango:                                                 5
#   cinnamon:                                              5
#   milk products:                                         5
#   sandwich spread:                                       5
#   frozen broccoli:                                       5
#   fruit pies:                                            5
#   vegetable samosas:                                     5
#   burrito (ready to eat):                                5
#   donuts:                                                5
#   chicken meat products:                                 5
#   instant coffee:                                        5
#   brownies:                                              5
#   cbd products:                                          5
#   halva:                                                 5
#   turkey based products:                                 5
#   ravioli:                                               5
#   frozen fish fillets:                                   5
#   carbonated beverage:                                   5
#   maize:                                                 4
#   dried fruits:                                          4
#   trouts:                                                4
#   coconut oil:                                           4
#   mackerel:                                              4
#   dried coconut:                                         4
#   marinated chicken meat:                                4
#   juice drink:                                           4
#   tahini (sesame paste):                                 4
#   flaxseed:                                              4
#   toffee:                                                4
#   coconut milk drink:                                    4
#   milk proteins:                                         4
#   mozzarella cheese:                                     4
#   cooked ham:                                            4
#   mixed vegetables:                                      4
#   juices:                                                4
#   cooked sausages:                                       4
#   fish and fish products:                                4
#   olive oil:                                             4
#   fermented beef meat:                                   4
#   other water-based drinks:                              4
#   meat, egg and dairy products:                          4
#   tzatziki sauce:                                        4
#   cumin powder:                                          4
#   croissants:                                            4
#   frozen hash browns:                                    4
#   energy and protein bars:                               4
#   dried figs:                                            4
#   lobster:                                               4
#   raw goat milk cheese:                                  4
#   frozen ready to eat products:                          4
#   chilled pork:                                          4
#   rum:                                                   4
#   green bean:                                            4
#   salad dressing:                                        4
#   bean sprouts:                                          4
#   spices:                                                4
#   protein balls:                                         4
#   chicken dippers:                                       4
#   boneless beef:                                         4
#   black pepper:                                          4
#   prepacked salad:                                       4
#   pretzels:                                              4
#   fruit salad:                                           4
#   vegetable mix:                                         4
#   pretzel stick:                                         4
#   ground beef meat:                                      4
#   blueberries:                                           4
#   guacamole:                                             4
#   rice cakes:                                            4
#   quinoa:                                                4
#   gorgonzola cheese:                                     4
#   spring water:                                          4
#   snack crackers:                                        4
#   spirits:                                               4
#   frozen poultry products:                               4
#   fresh cheese:                                          4
#   frozen ready to cook chicken:                          4
#   soy sauce:                                             4
#   drink powder:                                          3
#   caramel bites:                                         3
#   canned corn:                                           3
#   vitamins:                                              3
#   salami sticks:                                         3
#   cake decoration:                                       3
#   emulsifiers, stabilizers, thickeners and gelling agents:    3
#   bottled mineral water:                                 3
#   cabbage:                                               3
#   ricotta cheese:                                        3
#   spice mixture:                                         3
#   grissini breadsticks:                                  3
#   bitter apricot kernels:                                3
#   sardines:                                              3
#   water for human consumption:                           3
#   liquid egg white:                                      3
#   lollipops:                                             3
#   soups:                                                 3
#   Pangas catfishes (generic):                            3
#   soft drinks:                                           3
#   all purpose seasoning:                                 3
#   almond milk:                                           3
#   marshmalows:                                           3
#   lentils:                                               3
#   gluten free bread:                                     3
#   garlic powder:                                         3
#   bagels:                                                3
#   gravy mix:                                             3
#   bean paste:                                            3
#   bean sauce:                                            3
#   meat preparations:                                     3
#   wheat:                                                 3
#   fennel seeds:                                          3
#   meatloaf:                                              3
#   beef tongue:                                           3
#   melon seeds:                                           3
#   raw milk cheese:                                       3
#   energy drink:                                          3
#   mussels:                                               3
#   coconut drink:                                         3
#   mustard sauce:                                         3
#   various meat products:                                 3
#   squid:                                                 3
#   frozen dumplings with pork:                            3
#   chicken and chicken preparations:                      3
#   poultry meat and poultry meat products:                3
#   various pasta products:                                3
#   stuffed pastry:                                        3
#   hard cheese:                                           3
#   chilled chicken parts:                                 3
#   paella:                                                3
#   hazelnuts:                                             3
#   cooking sauce:                                         3
#   chilli peppers:                                        3
#   horseradish in jars:                                   3
#   hemp protein powder:                                   3
#   coffee drink:                                          3
#   chocolate and chocolate products:                      3
#   pasta sauce:                                           3
#   sweets:                                                3
#   vegan sausages:                                        3
#   veal meat:                                             3
#   chocolate spread:                                      3
#   chocolate wafers:                                      3
#   chorizo sausage:                                       3
#   cured pork meat:                                       3
#   chicken broth:                                         3
#   frozen chicken wings:                                  3
#   dietetic foods, food supplements, fortified foods:     3
#   clams (canned):                                        3
#   dried cranberries:                                     3
#   non-alcoholic beverages:                               3
#   cbd oil:                                               3
#   spreads:                                               3
#   pumpkin seeds:                                         3
#   dressing sauces:                                       3
#   various bakery products:                               3
#   vegetable ready to eat meals:                          3
#   vegetable preparation:                                 3
#   pop corn:                                              3
#   probiotic food supplement:                             3
#   custard:                                               3
#   various cheeses:                                       3
#   protein drink:                                         3
#   cheese dip:                                            3
#   frozen marinated beef:                                 2
#   frozen raw ground beef:                                2
#   fresh cut vegetables:                                  2
#   fresh parsley:                                         2
#   frozen beef trimmings:                                 2
#   frozen hamburgers:                                     2
#   frozen seafood:                                        2
#   frozen boneless beef:                                  2
#   frozen vegetables mix:                                 2
#   frozen pancakes:                                       2
#   frozen whole fish:                                     2
#   frozen pie:                                            2
#   frozen burgers:                                        2
#   frozen beef tongue:                                    2
#   fruit punch:                                           2
#   fruit snacks:                                          2
#   frozen lobster:                                        2
#   fruit bars:                                            2
#   soy milk product:                                      2
#   fresh beef:                                            2
#   cereal drink:                                          2
#   brown beans:                                           2
#   brown rice:                                            2
#   vodka:                                                 2
#   burrata:                                               2
#   vitamins supplement:                                   2
#   camembert:                                             2
#   canned chicken:                                        2
#   cherries:                                              2
#   chocolate drink powder:                                2
#   chicken meat meal:                                     2
#   chilled beef:                                          2
#   chilled pork sausages:                                 2
#   chilli paste:                                          2
#   vegetable based products:                              2
#   chocolate and hazelnut spread:                         2
#   chocolate and products therefor:                       2
#   broths:                                                2
#   brewer's yeast:                                        2
#   bread mix:                                             2
#   bread crumb:                                           2
#   whole chicken:                                         2
#   almond powder:                                         2
#   anchovies in oil:                                      2
#   white mould cheese:                                    2
#   white lasagna sauce:                                   2
#   assorted bread roll selection:                         2
#   white chocolate:                                       2
#   baguettes:                                             2
#   white cheese:                                          2
#   baklava:                                               2
#   bamboo:                                                2
#   bean snack:                                            2
#   blackberries:                                          2
#   bloody mary beverage mix:                              2
#   boar:                                                  2
#   chocolate confectionery:                               2
#   chocolate truffles:                                    2
#   fresh apples:                                          2
#   egg rolls:                                             2
#   dried chilli peppers:                                  2
#   dried fruit mix:                                       2
#   dried fruits with chocolate:                           2
#   dried shrimp noodles:                                  2
#   drinking chocolate powder:                             2
#   dry sausage:                                           2
#   egg products:                                          2
#   fajita meal:                                           2
#   cinnamon rolls:                                        2
#   filled chocolate:                                      2
#   flavoured potato chips:                                2
#   flavoured whey protein preparations:                   2
#   flavours:                                              2
#   vacuum packed beef:                                    2
#   foie gras:                                             2
#   french toast:                                          2
#   dried apples:                                          2
#   dried anchovies:                                       2
#   various beef products:                                 2
#   dietary capsules:                                      2
#   cod fillets:                                           2
#   goji berries:                                          2
#   confectionery for decoration:                          2
#   various prepared dishes:                               2
#   cottage cheese:                                        2
#   courgettes:                                            2
#   cous cous:                                             2
#   cream chocolate pie:                                   2
#   crisp cheese snack:                                    2
#   crispbread:                                            2
#   crustaceans and products thereof:                      2
#   cultivated fungi:                                      2
#   curry paste:                                           2
#   curry sauces:                                          2
#   diced beef:                                            2
#   concentrated apples:                                   2
#   yogurt raisins:                                        2
#   milk and milk products:                                2
#   soya drink:                                            2
#   lemonade (lemon soda):                                 2
#   scallops:                                              2
#   organic figs:                                          2
#   soybean:                                               2
#   potato croquettes:                                     2
#   pork shoulder:                                         2
#   ices and desserts:                                     2
#   seafood products:                                      2
#   iced tea:                                              2
#   seasoned chicken:                                      2
#   seasoning mix:                                         2
#   tea drink:                                             2
#   ice sticks:                                            2
#   hot dog sausages:                                      2
#   pork pie:                                              2
#   sushi:                                                 2
#   papaya:                                                2
#   seaweed preparations:                                  2
#   seeds mix:                                             2
#   orange juice:                                          2
#   lime:                                                  2
#   nuts mix:                                              2
#   rice noodles:                                          2
#   tomatoes:                                              2
#   minced chicken:                                        2
#   melons:                                                2
#   tilapia:                                               2
#   meat-salad:                                            2
#   rice flakes:                                           2
#   meat broth:                                            2
#   rice meal:                                             2
#   nut and fruit mixture:                                 2
#   prosciutto:                                            2
#   masala spice mix:                                      2
#   marzipan:                                              2
#   nut mix:                                               2
#   tiger nuts:                                            2
#   nuts and nuts products:                                2
#   lokoum:                                                2
#   liquorice:                                             2
#   sprinkles:                                             2
#   parmesan cheese:                                       2
#   sugar confectionary:                                   2
#   sweeteners:                                            2
#   swiss rolls:                                           2
#   pickled grape leaves:                                  2
#   pears:                                                 2
#   ground turmeric:                                       2
#   gouda:                                                 2
#   sorbets:                                               2
#   soy products:                                          2
#   pickled ginger:                                        2
#   pea shoots:                                            2
#   pastry tartlets:                                       2
#   pork and beef sausages:                                2
#   grated cheese:                                         2
#   table water:                                           2
#   pork belly:                                            2
#   pickled peppers:                                       2
#   turkey sandwich:                                       2
#   smoothie:                                              2
#   hemp tea:                                              2
#   pecorino cheese:                                       2
#   sliced bread:                                          2
#   gravy granules:                                        2
#   cheese - melted:                                       1
#   pine nuts:                                             1
#   cereal bars with chocolate:                            1
#   cheese burgers:                                        1
#   quorn preparation:                                     1
#   protein supplements:                                   1
#   cheese - made from raw milk:                           1
#   puffed rice:                                           1
#   cheese (taleggio capriolo):                            1
#   cereals and bakery products:                           1
#   sprinkle mix:                                          1
#   chocolate and strawberry flavoured cyclone milk:       1
#   pickled radish:                                        1
#   pork loins - frozen:                                   1
#   vegetable snack:                                       1
#   chocolate drinks:                                      1
#   canned spinach:                                        1
#   cantaloupe (fresh):                                    1
#   raw pork meat and raw pork meat preparations:          1
#   carbonated  water:                                     1
#   chocolate easter eggs with filling:                    1
#   raw milk goat's cheese:                                1
#   carbonated/sparkling water:                            1
#   carcasses of veal:                                     1
#   cardamom seeds:                                        1
#   sweet nut snack:                                       1
#   cardamon seeds:                                        1
#   carps, barbels and other cyprinids:                    1
#   raw milk cheese reblochon:                             1
#   cattle from which the milk was used to produce raw milk cheese:    1
#   raw cow's milk cheese:                                 1
#   raw beef meat and raw beef meat preparations:          1
#   chocolate dessert:                                     1
#   ramen noodles:                                         1
#   vinegar:                                               1
#   preserved red bean curd:                               1
#   plum bread &amp; butter pudding:                       1
#   chillies:                                              1
#   chicken slices:                                        1
#   chicken steak without bone:                            1
#   porcine lard:                                          1
#   chilli pickle:                                         1
#   sunflower oil:                                         1
#   chilli oil:                                            1
#   vegetable broth:                                       1
#   chilled beef preparations:                             1
#   chilled bengali cod curry:                             1
#   chilled vacuum packed beef:                            1
#   chilled boneless pork meat:                            1
#   chilled smoked ham:                                    1
#   chilled chicken thighs:                                1
#   pork carcass(es):                                      1
#   chilled ready to eat salad and side dishes:            1
#   chilled chicken wings:                                 1
#   chilled dumplings with meat:                           1
#   pork fillets:                                          1
#   chilled pork ribs:                                     1
#   pork shoulder - fresh:                                 1
#   vegetable burger:                                      1
#   canned meat stew:                                      1
#   prepared dish containing prawns:                       1
#   cheese flavoured snacks:                               1
#   cheese sausages:                                       1
#   chilled lasagne:                                       1
#   cheese tortilla:                                       1
#   cheese tray:                                           1
#   cheesy spirals:                                        1
#   squids:                                                1
#   prepared dish with chicken:                            1
#   starch:                                                1
#   powder seasoning:                                      1
#   vegetable crispbakes:                                  1
#   pomegranate:                                           1
#   vegetable cheese:                                      1
#   structured/textured fish meat products or fish paste:    1
#   prebaked apple pies:                                   1
#   chicken drumsticks:                                    1
#   chicken fillets:                                       1
#   prawn crackers:                                        1
#   canned mussels:                                        1
#   golden enoki mushrooms:                                1
#   canned fish products:                                  1
#   canned crab meat in brine:                             1
#   sesame oil:                                            1
#   assortment of filled chocolates:                       1
#   sesame confection:                                     1
#   baby food pouches:                                     1
#   baby foods:                                            1
#   semolina and products therefor:                        1
#   semi-hard cheeses:                                     1
#   seeds mixture:                                         1
#   seed mixe:                                             1
#   balsamic:                                              1
#   bamboo shoots:                                         1
#   bananas:                                               1
#   seasonings:                                            1
#   white bread flour:                                     1
#   white beans:                                           1
#   whisky:                                                1
#   batter mix:                                            1
#   seasoning sauce:                                       1
#   soya product:                                          1
#   wheat snack:                                           1
#   beef burrito:                                          1
#   seafood cocktail:                                      1
#   weight loss coffee:                                    1
#   beef stewed:                                           1
#   beef tallow:                                           1
#   asparagus:                                             1
#   sesame seed oil:                                       1
#   shark:                                                 1
#   soy yoghurt:                                           1
#   Dried pork meat:                                       1
#   yellow peas:                                           1
#   Groupers (generic):                                    1
#   soups, broths, sauces and condiments:                  1
#   Torpedo-shaped catfishes (generic):                    1
#   soft ripened cheese:                                   1
#   adobo seasoning:                                       1
#   after dinner mints:                                    1
#   soft cheese (creams):                                  1
#   soda drink:                                            1
#   snack mixture:                                         1
#   allspice:                                              1
#   sheep cheese:                                          1
#   almond kernels:                                        1
#   sichuan pepper:                                        1
#   white mustard seeds:                                   1
#   amaranth:                                              1
#   soya and products therefor:                            1
#   anchovy paste:                                         1
#   shrimp snacks:                                         1
#   animal by-products:                                    1
#   appetizers:                                            1
#   apple cake:                                            1
#   sheep milk cheese:                                     1
#   beef tenderloin cuts:                                  1
#   scones:                                                1
#   waxberry:                                              1
#   spicy tomato sauce:                                    1
#   breakfast cereals for babies:                          1
#   ricotta and spinach tortelloni pasta:                  1
#   rice vermicelli:                                       1
#   brioche:                                               1
#   rice sticks:                                           1
#   broccoli mix:                                          1
#   brown mushrooms:                                       1
#   rice flour:                                            1
#   brussel sprouts:                                       1
#   buffalo milk mozzarella cheese:                        1
#   chocolate flavoured cereals:                           1
#   rice cereal for children:                              1
#   roasted and caramelized peanuts:                       1
#   rice balls:                                            1
#   spinach leaves:                                        1
#   refreshments:                                          1
#   red pesto:                                             1
#   red chilli:                                            1
#   red chili:                                             1
#   ready-to-eat seafood sticks:                           1
#   canned artichoke hearts:                               1
#   canned black beans:                                    1
#   ready to eat meat product:                             1
#   ready cooked sliced chicken tikka breast:              1
#   breakfast cereals and products therefor:               1
#   roasted coffee:                                        1
#   beetroots:                                             1
#   blue poppy seeds:                                      1
#   watermelons:                                           1
#   beverage base of non-fruit origin, liquid:             1
#   bilberry extract used in a food supplement:            1
#   biscuit mix:                                           1
#   water for infants:                                     1
#   black caviar:                                          1
#   spaghetti sauce:                                       1
#   sparkling beverages:                                   1
#   blackcurrant drink concentrate:                        1
#   sauerkraut meal:                                       1
#   spice marinade:                                        1
#   sandwich filling:                                      1
#   roasted nuts:                                          1
#   salted radish:                                         1
#   boletus mushrooms, stems and pieces:                   1
#   bolognese sauce:                                       1
#   salted anchovies:                                      1
#   salami sausage:                                        1
#   spicy chicken skewers:                                 1
#   bovine fat:                                            1
#   bovine meat and offal:                                 1
#   spicy sauce:                                           1
#   saint marcelin cheese:                                 1
#   spicy tofu:                                            1
#   veal meat and offals:                                  1
#   pear juice:                                            1
#   chocolate flavoured meringues:                         1
#   frozen bourbon ribs:                                   1
#   fresh pork loin:                                       1
#   fresh poultry and poultry prepations:                  1
#   lemons:                                                1
#   lemon juice:                                           1
#   frozen beef lasagne:                                   1
#   turnips:                                               1
#   tortilla chips cheese:                                 1
#   ketchup:                                               1
#   jerky products:                                        1
#   frozen berries mix:                                    1
#   tortilla products:                                     1
#   frozen breaded turkey:                                 1
#   lentils stew:                                          1
#   instant drink/drinking powder:                         1
#   frozen burger buns:                                    1
#   instant cereal:                                        1
#   tuna salad:                                            1
#   frozen chicken strips with tendons:                    1
#   indian curry:                                          1
#   frozen cod fillets:                                    1
#   frozen cooked lobster meat:                            1
#   frozen diced chicken roast:                            1
#   frozen fish burgers:                                   1
#   frozen fish products:                                  1
#   fresh pork leg:                                        1
#   unpasteurised cheese:                                  1
#   chocolate mini muffins:                                1
#   lupin seeds:                                           1
#   fermented milk product:                                1
#   meat loaf:                                             1
#   meal replacement:                                      1
#   vacuum packed marinated pork:                          1
#   massala spice mixture:                                 1
#   fish sauce:                                            1
#   flavoured drinks:                                      1
#   flavoured fresh and creamy cheese spread:              1
#   flavoured milk:                                        1
#   flavoured soft drink:                                  1
#   margarine:                                             1
#   flounders, halibuts, soles:                            1
#   fresh lychees:                                         1
#   luncheon meat:                                         1
#   loose smoked whole chickens:                           1
#   unsalted organic crunchy peanut butter:                1
#   french beans / green beans:                            1
#   long grain rice:                                       1
#   fresh beef meat:                                       1
#   fresh broccoli:                                        1
#   liquid food supplement:                                1
#   limes:                                                 1
#   fresh dough:                                           1
#   fresh goat cheese:                                     1
#   frozen fried rice:                                     1
#   frozen grated coconut:                                 1
#   frozen green beans:                                    1
#   fruit salad with cantaloupe:                           1
#   frozen spring rolls:                                   1
#   frozen strawberry:                                     1
#   ground hot pepper:                                     1
#   frozen vegetarian cutlet:                              1
#   ground black pepper:                                   1
#   ground almonds:                                        1
#   fruit juice smoothie:                                  1
#   grilled seasoned chicken plate:                        1
#   green tea:                                             1
#   green raisins:                                         1
#   green pesto basil sauce:                               1
#   green basil pesto:                                     1
#   turbot flatfish (psetta maxima):                       1
#   garlic pickle:                                         1
#   grated cheese mixture:                                 1
#   garlic sausage:                                        1
#   ginger slices:                                         1
#   gingerbread:                                           1
#   ginseng powder:                                        1
#   grapes:                                                1
#   gnocchi:                                               1
#   gouda cheese:                                          1
#   goat cheese made from raw milk:                        1
#   goat meat:                                             1
#   frozen spinach:                                        1
#   frozen spicy chicken wings:                            1
#   frozen sliced coconut:                                 1
#   frozen seasoned potato wedges:                         1
#   frozen leek:                                           1
#   hot chilli and hot chilli products:                    1
#   frozen marinated chicken:                              1
#   hot chicken wings:                                     1
#   horses:                                                1
#   frozen peppers:                                        1
#   honeycomb:                                             1
#   turnip leaves in sunflower seed oil:                   1
#   frozen pork meat:                                      1
#   high protein bars:                                     1
#   frozen pork ribs:                                      1
#   frozen pork trimmings:                                 1
#   frozen potatoes:                                       1
#   herbs:                                                 1
#   soy bean paste:                                        1
#   frozen poultry preparations:                           1
#   herbal tea:                                            1
#   frozen prepared dish of chicken tikka masala with pilau rice:    1
#   herbal premix:                                         1
#   hemp oil:                                              1
#   frozen sausage rolls:                                  1
#   frozen sausages:                                       1
#   ham slices:                                            1
#   meat samosas, vegetable samosas, chicken samosas and meat spring rolls:    1
#   mechanically separated chicken meat:                   1
#   fats and oils:                                         1
#   cranberry jam:                                         1
#   cooked meat products:                                  1
#   paprika:                                               1
#   tarragon:                                              1
#   tasty trio condiment selection:                        1
#   various poultry meat:                                  1
#   oyster sauce:                                          1
#   cottage pie:                                           1
#   tea bags:                                              1
#   other fruit and vegetable juice products:              1
#   other food product / mixed:                            1
#   testosterone booster:                                  1
#   cranberry juice:                                       1
#   cured loin:                                            1
#   organic tofu:                                          1
#   organic tea:                                           1
#   crepe mix:                                             1
#   organic dates:                                         1
#   organic coconut oil:                                   1
#   organic coconut flour:                                 1
#   crushed red pepper:                                    1
#   organic chlorella powder:                              1
#   organic chilled hummus:                                1
#   oregano:                                               1
#   orange sugar paste:                                    1
#   cooked chicken skewer:                                 1
#   various ready-to-eat meat products:                    1
#   parmesan cheese grated:                                1
#   various snacks:                                        1
#   chocolate mousse:                                      1
#   pickled gherkins in glass jar:                         1
#   chocolate spelt balls:                                 1
#   pickled figs, cherries, pears and walnuts:             1
#   chocolate spread with hazelnuts:                       1
#   pickled cucumber:                                      1
#   pickled beetroot:                                      1
#   varnishes and coatings:                                1
#   pesto sauce (pesto verde):                             1
#   syrup:                                                 1
#   pepperoni:                                             1
#   peppermint:                                            1
#   cocktail sausage rolls:                                1
#   table water and soda water:                            1
#   coconut sugar:                                         1
#   various vegetable preparations:                        1
#   taco sauce:                                            1
#   pasteurized cow milk cheese:                           1
#   tallegio (cheese):                                     1
#   tapioca chips:                                         1
#   cola drink:                                            1
#   colours:                                               1
#   parsnip:                                               1
#   curd cheese:                                           1
#   orange peppers:                                        1
#   millet porridge:                                       1
#   mixed salad:                                           1
#   multi vitamin food supplement:                         1
#   dried garlic:                                          1
#   dried herb powder ashwagandha (withania somnifera):    1
#   dried lilies:                                          1
#   dried pangash:                                         1
#   moussaka:                                              1
#   dried pork sausages:                                   1
#   dried sausage:                                         1
#   dried shitake mushrooms (lentinula edodes):            1
#   mixed spices:                                          1
#   dried strawberries:                                    1
#   mixed nuts:                                            1
#   cured smoked ham:                                      1
#   dry ham:                                               1
#   mix of nuts:                                           1
#   mint chocolate:                                        1
#   vacuum packed sliced ham:                              1
#   edam cheese:                                           1
#   mineral waters:                                        1
#   egg salad with ham:                                    1
#   eggplants:                                             1
#   vacuum packed pork ear roll:                           1
#   eggs and egg products:                                 1
#   minced beef meat:                                      1
#   mung bean sprouts:                                     1
#   nacho chips:                                           1
#   dried fruit in jars:                                   1
#   natural honey:                                         1
#   thyme:                                                 1
#   octopus:                                               1
#   nuts, nut products and seeds:                          1
#   cuttlefish:                                            1
#   various fish products:                                 1
#   various chilled or frozen pork products:               1
#   deboned chicken thighs:                                1
#   various chicken meat products:                         1
#   nutrition shake:                                       1
#   nutmeg:                                                1
#   nut-almond mixture:                                    1
#   dipping sauce:                                         1
#   nut mixture:                                           1
#   nut bars:                                              1
#   dried almonds:                                         1
#   nut and raisin mix:                                    1
#   vanilla powder:                                        1
#   dried beans:                                           1
#   vanilla drink:                                         1
#   dried brown beans:                                     1
#   nougat:                                                1
#   non-alcoholic beer:                                    1
#   dried elder berries:                                   1
#   frozen poultry meat:                                   1

# %% [markdown]
# - It is clear that the `product` column exhibits an `imbalance` in the distribution of its values.
#     - The product column demonstrates `a long right skew`, indicating that `a small number of categories dominate the dataset`, while most other categories occur infrequently. This imbalance highlights the need for targeted data augmentation or resampling techniques to ensure the model adequately learns from underrepresented classes.
# - **So, all `y` columns are imbalanced**.

# %% [markdown]
# ## Data Augmentation
# - In this section, we will implement the necessary code to generate `synthetic data for the minority classes`, addressing the imbalance in the dataset. This process will help improve model performance by ensuring that all classes are adequately represented during training.
# - Firslty we will need to download the following:
#     - **`nltk.download('punkt')`**: Downloads the Punkt tokenizer for sentence and word tokenization.
#     - **`nltk.download('wordnet')`**: Downloads the WordNet lexical database for synonyms, antonyms, and word relationships.
#     - **`nltk.download('stopwords')`**: Downloads a list of stop words (e.g., "the", "and") for text preprocessing.
#     - **`stop_words = set(nltk.corpus.stopwords.words('english'))`**: Loads English stop words into a set for efficient filtering.
#     - **`from nltk.corpus import wordnet`**: Imports WordNet for use in text processing.

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))
# try:
#     nltk.data.find('wordnet.zip')
# except:
#     nltk.download('wordnet', download_dir='/kaggle/working/')
#     command = "unzip /kaggle/working/corpora/wordnet.zip -d /kaggle/working/corpora"
#     subprocess.run(command.split())
#     nltk.data.path.append('/kaggle/working/')

# Now you can import the NLTK resources as usual
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to /Users/evangelia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/evangelia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/evangelia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# - We will create the function `get_synonyms` for generatig synonyms words.
#     - It will be helpful for our aim being data augmentation

# %%
def get_synonyms(word):
    """
    Retrieves a list of synonyms for a given word using the WordNet lexical database.

    :param word: str
        The word for which synonyms are to be fetched.
    
    :return: list
        A list of unique synonyms for the input word.
    
    :example:
        >>> get_synonyms("happy")
        ['felicitous', 'glad', 'happy', 'elated', 'joyful']
    """
    synonyms = set()  # Use a set to avoid duplicate synonyms.
    for syn in wordnet.synsets(word):  # Iterate over all synsets (meanings) of the word.
        for lemma in syn.lemmas():  # Access each lemma (word variant) of the synset.
            synonyms.add(lemma.name())  # Add the lemma name to the synonyms set.
    return list(synonyms)  # Convert the set to a list before returning.

# %% [markdown]
# - - **`augment_text`**: Generates augmented versions of input text by replacing words with synonyms and randomly adding or removing words, creating diverse variations of the original sentence.

# %%
def augment_text(text, num_augments=1):
    """
    Generates augmented versions of the input text by replacing words with their synonyms 
    and randomly adding or removing words.

    :param text: str
        The input text to be augmented.
    :param num_augments: int, optional (default=1)
        The number of augmented versions of the input text to generate.
    
    :return: list
        A list containing `num_augments` augmented versions of the input text.
    
    :example:
        >>> augment_text("The quick brown fox jumps", num_augments=2)
        ['The quick brown fox leaps', 'The swift brown fox']
    """
    augmented_texts = []
    words = word_tokenize(text)  # Tokenize the input text into words.
    
    for _ in range(num_augments):
        augmented_text = words.copy()
        
        # Replace words with synonyms
        for i, word in enumerate(words):
            synonyms = get_synonyms(word)  # Fetch synonyms for the word.
            if synonyms:
                augmented_text[i] = random.choice(synonyms)  # Randomly replace with a synonym.
        
        # Randomly add or remove a word
        if random.random() < 0.5: 
            augmented_text.append(random.choice(words))  # Add a random word from the original text.
        else:
            if len(augmented_text) > 1:
                augmented_text.remove(random.choice(augmented_text))  # Remove a random word.
        
        # Join the augmented words back into a single string and add to results
        augmented_texts.append(' '.join(augmented_text))
    
    return augmented_texts

# %% [markdown]
# - **`balance_dataframe`**: Balances a DataFrame by generating augmented samples for underrepresented classes in the target column, using a specified augmentation ratio. This ensures more equitable representation of all classes for training.

# %%
def balance_dataframe(df, target_column, ratio=0.2):
    """
    Balances a DataFrame by augmenting data for underrepresented classes in the target column.

    :param df: pd.DataFrame
        The input DataFrame to be balanced. It must include the target column 
        and other necessary columns (e.g., 'title', 'text') for augmentation.
    :param target_column: str
        The name of the column containing the target labels/classes to balance.
    :param ratio: float, optional (default=0.2)
        The ratio of augmentation to perform for underrepresented classes compared 
        to the most represented class. Determines how many synthetic samples are generated.
    
    :return: pd.DataFrame
        The balanced DataFrame with augmented rows added for underrepresented classes.
    
    :example:
        >>> balanced_df = balance_dataframe(df, target_column='category', ratio=0.3)
    """
    max_count = df[target_column].value_counts().max() #maybe could change, im checking anything that is below the max, maybe we should do it below max/3 or something
    
    for label in df[target_column].unique():
        label_df = df[df[target_column] == label]
        count_label = len(label_df)
        
        if count_label < max_count:
            samples_to_generate = int((max_count // count_label) * ratio)
            
            augmented_data = []
            
            for i in range(samples_to_generate):
                row = label_df.sample(1).iloc[0]
                
                augmented_title = augment_text(row['title'])[0] 
                augmented_text = augment_text(row['text'])[0]    
                
                new_row = row.copy()
                new_row['title'] = augmented_title
                new_row['text'] = augmented_text     
                
                augmented_data.append(new_row)
            
            
            augmented_df = pd.DataFrame(augmented_data)
            df = pd.concat([df, augmented_df], ignore_index=True)
    
    return df

# %% [markdown]
# - Firstly, we call the function `balance_dataframe` for the column `hazard`.
#     - Note: many `y` (that is `hazard`, `hazard-category`, `product`, `product-category`) columns share common `x` (taht is `text` and `title`) inputs.

# %%
balanced = balance_dataframe(data,"hazard")

# %%
balanced
# Out:
#       year  month  day country  \
# 0     1994      1    7      us
# 1     1994      3   10      us
# 2     1994      3   28      us
# 3     1994      4    3      us
# 4     1994      7    1      us
# ...    ...    ...  ...     ...
# 7572  2021     12   17      ie
# 7573  2022      1   28      ie
# 7574  2021     12   23      ie
# 7575  2021      8   26      ie
# 7576  2021     12   23      ie
#
#                                                   title  \
# 0                      Recall Notification: FSIS-024-94
# 1                      Recall Notification: FSIS-033-94
# 2                      Recall Notification: FSIS-014-94
# 3                      Recall Notification: FSIS-009-94
# 4                      Recall Notification: FSIS-001-94
# ...                                                 ...
# 7572  think of Kama hemp CBD oil referable to the co...
# 7573  call_up of type_A peck of Hempture CBD anele a...
# 7574  call_back of deoxyadenosine_monophosphate batc...
# 7575  think of Vita D ’ Beaver_State Bio organic hem...
# 7576  think deoxyadenosine_monophosphate hatful of w...
#
#                                                    text hazard-category  \
# 0     Case Number: 024-94   \n            Date Opene...      biological
# 1     Case Number: 033-94   \n            Date Opene...      biological
# 2     Case Number: 014-94   \n            Date Opene...      biological
# 3     Case Number: 009-94   \n            Date Opene...  foreign bodies
# 4     Case Number: 001-94   \n            Date Opene...  foreign bodies
# ...                                                 ...             ...
# 7572  come_back of Kama hemp CBD oil_color imputable...        chemical
# 7573  recollect of a quite_a_little of Hempture CBD ...        chemical
# 7574  recall of angstrom great_deal of orbicular Bot...        chemical
# 7575  withdraw of Vita D ’ operating_room Bio consti...        chemical
# 7576  withdraw of a mountain of ball-shaped CBD libr...        chemical
#
#                                   product-category  \
# 0                     meat, egg and dairy products
# 1                     meat, egg and dairy products
# 2                     meat, egg and dairy products
# 3                     meat, egg and dairy products
# 4                     meat, egg and dairy products
# ...                                            ...
# 7572                    other food product / mixed
# 7573                    other food product / mixed
# 7574                    other food product / mixed
# 7575  cocoa and cocoa preparations, coffee and tea
# 7576                    other food product / mixed
#
#                                               hazard  \
# 0                             listeria monocytogenes
# 1                                       listeria spp
# 2                             listeria monocytogenes
# 3                                   plastic fragment
# 4                                   plastic fragment
# ...                                              ...
# 7572  too high content of tetrahydrocannabinol (THC)
# 7573  too high content of tetrahydrocannabinol (THC)
# 7574  too high content of tetrahydrocannabinol (THC)
# 7575  too high content of tetrahydrocannabinol (THC)
# 7576  too high content of tetrahydrocannabinol (THC)
#
#                           product
# 0                  smoked sausage
# 1                         sausage
# 2                      ham slices
# 3     thermal processed pork meat
# 4                  chicken breast
# ...                           ...
# 7572                      cbd oil
# 7573                      cbd oil
# 7574                 cbd products
# 7575                     hemp tea
# 7576                 cbd products
#
# [7577 rows x 10 columns]

# %% [markdown]
# - We can observe that the total number of rows increased.
#     - Now, being equal to `7577` (the initial rows were equal to 5082).
# - **`plot_balanced`**: Creates side-by-side bar plots to compare the distribution of a categorical column in the original and balanced DataFrames, highlighting the effects of data balancing.
# - **General Note**: We decided to "hold" the imbalance of classes for example we added extra data for the  high supported classes, too. TODO

# %%
def plot_balanced(old_df, new_df, column_name):
    """
    Plots a side-by-side comparison of the distribution of a categorical column
    before and after balancing.

    :param old_df: pd.DataFrame
        The original DataFrame before balancing.
    :param new_df: pd.DataFrame
        The balanced DataFrame after augmentation.
    :param column_name: str
        The name of the column (categorical) to visualize and compare distributions.
    
    :return: None
        Displays the plots showing the count distributions of the specified column
        for the original and balanced DataFrames.
    
    :example:
        >>> plot_balanced(old_df, new_df, column_name="category")
    """
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    # Original DataFrame
    sns.countplot(data=old_df, x=column_name, ax=axes[0], hue=column_name, palette="Set2", legend=False)
    axes[0].set_title(f"Original {column_name} Distribution")
    axes[0].set_xlabel(column_name)
    axes[0].set_ylabel("Count")
    axes[0].tick_params(axis='x', which='both', bottom=False, labelbottom=False)  # Hide x-axis labels

    # Balanced DataFrame
    sns.countplot(data=new_df, x=column_name, ax=axes[1], hue=column_name, palette="Set2", legend=False)
    axes[1].set_title(f"Balanced {column_name} Distribution")
    axes[1].set_xlabel(column_name)
    axes[1].set_ylabel("Count")
    axes[1].tick_params(axis='x', which='both', bottom=False, labelbottom=False)  # Hide x-axis labels

    
    plt.tight_layout()  
    plt.show()

# %% [markdown]
# - Let's call the function `plot_balanced` for each of our `y` labels.

# %%
plot_balanced(data, balanced, 'hazard-category')
plot_balanced(data, balanced, 'product-category')
plot_balanced(data, balanced, 'hazard')
plot_balanced(data, balanced, 'product')

# %% [markdown]
# - Observing the plot above, we can observe that some valeus in classes (in the right) has been increased.
# - We call the function `balance_dtafarme` for the column `hazard-category` and we replot via the function `plot_balance`.
#     - This process buld on the already modified dataset that is `balanced` (first call).

# %%
balanced_2 = balance_dataframe(balanced,"hazard-category")

# %%
plot_balanced(balanced, balanced_2, 'hazard-category')
plot_balanced(balanced, balanced_2, 'product-category')
plot_balanced(balanced, balanced_2, 'hazard')
plot_balanced(balanced, balanced_2,'product')

# %% [markdown]
# - Running the process in the second time, and obserning the diagrams above, it is obvious that the data are more balance as the number of minor classes have been increased.
# - We will move on via re-calling the function `balance_dataframe` for the column `product-category`.
# - Then we will re-plot the new "balanced" using the function `plot_balance`.

# %%
balanced_3 = balance_dataframe(balanced_2,"product-category")

# %%
plot_balanced(balanced_2, balanced_3, 'hazard-category')
plot_balanced(balanced_2, balanced_3, 'product-category')
plot_balanced(balanced_2, balanced_3, 'hazard')
plot_balanced(balanced_2, balanced_3,'product')

# %% [markdown]
# - Again obserining the plots, in some values if classes then number of instances has been increased.
# - We will re-run a last time, but now for the column `produt`.

# %%
balanced_4 = balance_dataframe(balanced_3,"product",ratio=0.05)

# %%
plot_balanced(balanced_3, balanced_4, 'hazard-category')
plot_balanced(balanced_3, balanced_4, 'product-category')
plot_balanced(balanced_3, balanced_4, 'hazard')
plot_balanced(balanced_3, balanced_4,'product')

# %% [markdown]
# - The intresting effect of this run is for the `product` column as the majority of values has been increased compared to the original one.

# %%
balanced_4
# Out:
#        year  month  day country  \
# 0      1994      1    7      us
# 1      1994      3   10      us
# 2      1994      3   28      us
# 3      1994      4    3      us
# 4      1994      7    1      us
# ...     ...    ...  ...     ...
# 13594  2022      7   19      hk
# 13595  2022      7   19      hk
# 13596  2022      7   19      hk
# 13597  2022      7   19      hk
# 13598  2022      7   19      hk
#
#                                                    title  \
# 0                       Recall Notification: FSIS-024-94
# 1                       Recall Notification: FSIS-033-94
# 2                       Recall Notification: FSIS-014-94
# 3                       Recall Notification: FSIS-009-94
# 4                       Recall Notification: FSIS-001-94
# ...                                                  ...
# 13594  Cf barrack world not to eat_up genial of trans...
# 13595  inspire public non to take_in variety of cup a...
# 13596  cystic_fibrosis inspire world non to waste sor...
# 13597  cystic_fibrosis urge world non to ware variety...
# 13598  mucoviscidosis recommend populace not to eat_u...
#
#                                                     text hazard-category  \
# 0      Case Number: 024-94   \n            Date Opene...      biological
# 1      Case Number: 033-94   \n            Date Opene...      biological
# 2      Case Number: 014-94   \n            Date Opene...      biological
# 3      Case Number: 009-94   \n            Date Opene...  foreign bodies
# 4      Case Number: 001-94   \n            Date Opene...  foreign bodies
# ...                                                  ...             ...
# 13594  atomic_number_98 root_on world not to devour v...        chemical
# 13595  CF itch world not to eat_up genial of transfus...        chemical
# 13596  pancreatic_fibrosis pep_up populace not to go_...        chemical
# 13597  fibrocystic_disease_of_the_pancreas urge popul...        chemical
# 13598  Cf root_on world non to have tolerant of trans...        chemical
#
#                    product-category                                 hazard  \
# 0      meat, egg and dairy products                 listeria monocytogenes
# 1      meat, egg and dairy products                           listeria spp
# 2      meat, egg and dairy products                 listeria monocytogenes
# 3      meat, egg and dairy products                       plastic fragment
# 4      meat, egg and dairy products                       plastic fragment
# ...                             ...                                    ...
# 13594    other food product / mixed  unauthorised substance ethylene oxide
# 13595    other food product / mixed  unauthorised substance ethylene oxide
# 13596    other food product / mixed  unauthorised substance ethylene oxide
# 13597    other food product / mixed  unauthorised substance ethylene oxide
# 13598    other food product / mixed  unauthorised substance ethylene oxide
#
#                            product
# 0                   smoked sausage
# 1                          sausage
# 2                       ham slices
# 3      thermal processed pork meat
# 4                   chicken breast
# ...                            ...
# 13594                ramen noodles
# 13595                ramen noodles
# 13596                ramen noodles
# 13597                ramen noodles
# 13598                ramen noodles
#
# [13599 rows x 10 columns]

# %% [markdown]
# ### Compare Original Distribution of `y` with the Augmented Data

# %%
print("Shape of the Initial Data Frame: ",data[['hazard-category', 'product-category', 'hazard', 'product']].shape[0]) # shape of **initial** dataframe
print("Shape of the Transformed-Balanced Data Frame: ",balanced_4[['hazard-category', 'product-category', 'hazard', 'product']].shape[0]) # shape of **balanced-trasformed** dataframe
# Out:
# Shape of the Initial Data Frame:  5082
# Shape of the Transformed-Balanced Data Frame:  13599

# %%
abs(data[['hazard-category', 'product-category', 'hazard', 'product']].shape[0] - balanced_4[['hazard-category', 'product-category', 'hazard', 'product']].shape[0])
# Out:
# 8517

# %% [markdown]
# - Following the application of data augmentation, the dataset expanded by an `additional 8,527 rows`.
# - **`compare_augmentation_effects`**: Analyzes and visualizes the impact of data augmentation by comparing unique value counts for specified columns in the original and augmented datasets. It generates side-by-side bar plots with counts above the bars, allowing for a clear comparison of top or bottom values.
#     - **`show_top`**: A boolean argument that determines which rows to display in the comparison:
#         - **`True`** (default): Displays the top 10 rows with the highest counts.
#         - **`False`**: Displays the bottom 10 rows with the lowest counts.
#     - This arguments is crucial for columns (like `hazard`, `product` having many-many values).

# %%
def compare_augmentation_effects(original_df, augmented_df, columns, show_top=True):
    """
    Compares the increase in unique value counts for specified columns 
    between the original and augmented datasets using side-by-side bar plots.

    :param original_df: pd.DataFrame
        The original DataFrame before augmentation.
    :param augmented_df: pd.DataFrame
        The augmented DataFrame after augmentation.
    :param columns: list
        List of column names to analyze.
    :param show_top: bool, optional (default=True)
        If True, shows the top 10 rows with the highest counts.
        If False, shows the bottom 10 rows with the lowest counts.
    :return: None
        Displays comparison tables and side-by-side bar plots with counts above bars for each column.
    """

    def plot_comparison(comparison, column, title_suffix):
        """
        Helper function to plot a bar chart for the given comparison DataFrame.

        :param comparison: pd.DataFrame
            The DataFrame containing the counts to plot.
        :param column: str
            The name of the column being analyzed.
        :param title_suffix: str
            A suffix to include in the plot title for clarification.
        """
        ax = comparison.plot(
            kind="bar",
            figsize=(12, 6),
            color=["skyblue", "salmon"],
            edgecolor="black"
        )
        plt.title(f"Comparison of '{column}' {title_suffix}", fontsize=14)
        plt.xlabel(column, fontsize=12)
        plt.ylabel("Counts", fontsize=12)
        plt.xticks(rotation=45, fontsize=10)
        plt.legend(title="Dataset", labels=["Original", "Augmented"], fontsize=10)
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        # Add numbers above bars
        for p in ax.patches:
            ax.annotate(
                f"{p.get_height():,}",  # Add formatted number
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center",
                va="bottom",
                fontsize=10,
                color="black"
            )
        plt.tight_layout()
        plt.show()

    for column in columns:
        print(f"\n### Column: {column} ###")

        # Calculate value counts
        original_counts = original_df[column].value_counts()
        augmented_counts = augmented_df[column].value_counts()

        # Merge counts into a comparison DataFrame
        comparison = pd.DataFrame({
            "Original": original_counts,
            "Augmented": augmented_counts
        }).fillna(0).astype(int)  # Ensure missing values are filled and converted to integers

        # Sort the DataFrame
        comparison = comparison.sort_values(by="Augmented", ascending=False)

        # Select rows to display (top 10 or bottom 10)
        rows_to_display = comparison.head(10) if show_top else comparison.tail(10)

        # Print comparison table
        print(rows_to_display)

        # Plot the comparison
        plot_comparison(rows_to_display, column, "Before and After Augmentation (Top 10)" if show_top else "Before and After Augmentation (Bottom 10)")

# %% [markdown]
# ### Compare Effect of Data Augmentation for 10 Low Classes for the DataFrame `balanced_4`

# %% [markdown]
# - In the following tables and plots, we can see for each `y` the effect of data augmentation (syntheti data) for the values belonging to low classes (low supported classes).
#     - We will observe an `increase stemming from the data augmentation`.

# %%
columns_to_compare = ['hazard-category', 'product-category', 'hazard', 'product']
compare_augmentation_effects(data, balanced_4, columns_to_compare, show_top=False)
# Out:
# ### Column: hazard-category ###
#                                 Original  Augmented
# hazard-category
# allergens                           1854       4313
# biological                          1741       3856
# chemical                             287       1643
# fraud                                371       1402
# foreign bodies                       561       1266
# other hazard                         134        515
# packaging defect                      54        195
# organoleptic aspects                  53        193
# migration                              3        144
# food additives and flavourings        24         72
# ### Column: product-category ###
#                                 Original  Augmented
# product-category
# ices and desserts                    222        314
# other food product / mixed            55        237
# alcoholic beverages                   59        191
# food contact materials                 7        177
# fats and oils                         19        158
# sugars and syrups                      5         87
# pet feed                              20         79
# honey and royal jelly                  8         76
# feed materials                         6         55
# food additives and flavourings         8         50
# ### Column: hazard ###
#                                                  Original  Augmented
# hazard
# pathogenic bacteria                                     7         27
# hazelnut                                               16         26
# undeclared constituent                                  7         26
# cyclospora                                             10         25
# specified risk material (srm)                           9         25
# misbranding                                            13         25
# other not classified hazards for foreign bodies         8         24
# patulin                                                10         23
# other not classified biological hazards                13         23
# Aflatoxin                                              10         23
# ### Column: product ###
#                          Original  Augmented
# product
# parsley                         3          6
# spice mix                       3          6
# spices                          3          6
# coconut milk drink              4          6
# energy drink                    3          6
# cod                             3          6
# energy and protein bars         4          6
# bottled mineral water           3          6
# spirits                         4          6
# horseradish in jars             3          6

# %% [markdown]
# ### Compare Effect of Data Augmentation for 10 High Classes for the DataFrame `balanced_4`
# - In the following tables and plots, we can see for each `y` the effect of data augmentation (syntheti data) for the values belonging to high classes (high supported classes).
#     - We will observe an `increase stemming from the data augmentation`.

# %%
columns_to_compare = ['hazard-category', 'product-category', 'hazard', 'product']
compare_augmentation_effects(data, balanced_4, columns_to_compare, show_top=True)
# Out:
# ### Column: hazard-category ###
#                                 Original  Augmented
# hazard-category
# allergens                           1854       4313
# biological                          1741       3856
# chemical                             287       1643
# fraud                                371       1402
# foreign bodies                       561       1266
# other hazard                         134        515
# packaging defect                      54        195
# organoleptic aspects                  53        193
# migration                              3        144
# food additives and flavourings        24         72
# ### Column: product-category ###
#                                               Original  Augmented
# product-category
# meat, egg and dairy products                      1434       3592
# fruits and vegetables                              535       1675
# cereals and bakery products                        671       1261
# prepared dishes and snacks                         469       1059
# seafood                                            268        774
# soups, broths, sauces and condiments               264        675
# nuts, nut products and seeds                       262        599
# herbs and spices                                   125        580
# non-alcoholic beverages                            134        533
# cocoa and cocoa preparations, coffee and tea       210        496
# ### Column: hazard ###
#                                                 Original  Augmented
# hazard
# listeria monocytogenes                               665       1347
# salmonella                                           621       1310
# milk and products thereof                            588       1262
# cereals containing gluten and products thereof       207        510
# other                                                102        469
# peanuts and products thereof                         211        459
# eggs and products thereof                            208        440
# escherichia coli                                     237        434
# plastic fragment                                     206        403
# soybeans and products thereof                        170        335
# ### Column: product ###
#                            Original  Augmented
# product
# ice cream                       185        225
# chicken based products          138        199
# plastics                          6        165
# cakes                            93        110
# ready to eat - cook meals        79         96
# cookies                          78         86
# pet feed                         20         79
# beer                             25         76
# cheese                           74         76
# sausage                          38         73

# %% [markdown]
# ### Compare Effect of Data Augmentation for 10 Low Classes for the DataFrame `balanced_3`

# %%
columns_to_compare = ['hazard-category', 'product-category', 'hazard', 'product']
compare_augmentation_effects(data, balanced_3, columns_to_compare, show_top=False)
# Out:
# ### Column: hazard-category ###
#                                 Original  Augmented
# hazard-category
# allergens                           1854       2118
# biological                          1741       2090
# chemical                             287       1248
# fraud                                371        849
# foreign bodies                       561        721
# other hazard                         134        352
# organoleptic aspects                  53        181
# migration                              3        144
# packaging defect                      54        123
# food additives and flavourings        24         46
# ### Column: product-category ###
#                                 Original  Augmented
# product-category
# herbs and spices                     125        210
# food contact materials                 7        166
# alcoholic beverages                   59        161
# fats and oils                         19        118
# other food product / mixed            55        111
# sugars and syrups                      5         87
# pet feed                              20         79
# honey and royal jelly                  8         65
# feed materials                         6         44
# food additives and flavourings         8         41
# ### Column: hazard ###
#                                          Original  Augmented
# hazard
# sulphates/sulphites                             9         23
# staphylococcus                                  9         23
# cyclospora                                     10         23
# enteroviruses                                  10         23
# high content of cyanide                         9         23
# improper conditions                            13         23
# patulin                                        10         23
# misbranding                                    13         23
# other not classified biological hazards        13         23
# Aflatoxin                                      10         23
# ### Column: product ###
#                                           Original  Augmented
# product
# plum bread &amp; butter pudding                  1          1
# fermented milk product                           1          1
# filled chocolate                                 1          1
# pine nuts                                        1          1
# fish sauce                                       1          1
# pickled radish                                   1          1
# flavoured drinks                                 1          1
# flavoured fresh and creamy cheese spread         1          1
# pickled gherkins in glass jar                    1          1
# ham slices                                       1          1

# %% [markdown]
# ### Compare Effect of Data Augmentation for 10 High Classes for the DataFrame `balanced_3`

# %%
columns_to_compare = ['hazard-category', 'product-category', 'hazard', 'product']
compare_augmentation_effects(data, balanced_3, columns_to_compare, show_top=True)
# Out:
# ### Column: hazard-category ###
#                                 Original  Augmented
# hazard-category
# allergens                           1854       2118
# biological                          1741       2090
# chemical                             287       1248
# fraud                                371        849
# foreign bodies                       561        721
# other hazard                         134        352
# organoleptic aspects                  53        181
# migration                              3        144
# packaging defect                      54        123
# food additives and flavourings        24         46
# ### Column: product-category ###
#                                               Original  Augmented
# product-category
# meat, egg and dairy products                      1434       2064
# cereals and bakery products                        671        849
# fruits and vegetables                              535        727
# prepared dishes and snacks                         469        558
# seafood                                            268        462
# soups, broths, sauces and condiments               264        348
# nuts, nut products and seeds                       262        341
# cocoa and cocoa preparations, coffee and tea       210        323
# non-alcoholic beverages                            134        288
# confectionery                                      170        287
# ### Column: hazard ###
#                                                 Original  Augmented
# hazard
# listeria monocytogenes                               665        667
# salmonella                                           621        624
# milk and products thereof                            588        589
# other                                                102        246
# escherichia coli                                     237        237
# plastic fragment                                     206        236
# cereals containing gluten and products thereof       207        224
# peanuts and products thereof                         211        211
# eggs and products thereof                            208        209
# metal fragment                                       155        190
# ### Column: product ###
#                            Original  Augmented
# product
# ice cream                       185        225
# chicken based products          138        199
# plastics                          6        165
# cakes                            93        110
# ready to eat - cook meals        79         96
# cookies                          78         86
# pet feed                         20         79
# cheese                           74         76
# beer                             25         76
# sausage                          38         73

# %% [markdown]
# - Now, we will save the data-augmented datafarme to `csv` named `data_augmented_incidents_train.csv` only for the datafarme `balanced_4` as `balanced_3` in some classes has only 1 data. This is problimatic (many problems liek breaks SMOTE code next due to neigthbours boud).

# %%
# balanced_4.to_csv("data_augmented_incidents_train.csv", index=False) # save data augmented data.

# %%
balanced_4
# Out:
#        year  month  day country  \
# 0      1994      1    7      us
# 1      1994      3   10      us
# 2      1994      3   28      us
# 3      1994      4    3      us
# 4      1994      7    1      us
# ...     ...    ...  ...     ...
# 13594  2022      7   19      hk
# 13595  2022      7   19      hk
# 13596  2022      7   19      hk
# 13597  2022      7   19      hk
# 13598  2022      7   19      hk
#
#                                                    title  \
# 0                       Recall Notification: FSIS-024-94
# 1                       Recall Notification: FSIS-033-94
# 2                       Recall Notification: FSIS-014-94
# 3                       Recall Notification: FSIS-009-94
# 4                       Recall Notification: FSIS-001-94
# ...                                                  ...
# 13594  Cf barrack world not to eat_up genial of trans...
# 13595  inspire public non to take_in variety of cup a...
# 13596  cystic_fibrosis inspire world non to waste sor...
# 13597  cystic_fibrosis urge world non to ware variety...
# 13598  mucoviscidosis recommend populace not to eat_u...
#
#                                                     text hazard-category  \
# 0      Case Number: 024-94   \n            Date Opene...      biological
# 1      Case Number: 033-94   \n            Date Opene...      biological
# 2      Case Number: 014-94   \n            Date Opene...      biological
# 3      Case Number: 009-94   \n            Date Opene...  foreign bodies
# 4      Case Number: 001-94   \n            Date Opene...  foreign bodies
# ...                                                  ...             ...
# 13594  atomic_number_98 root_on world not to devour v...        chemical
# 13595  CF itch world not to eat_up genial of transfus...        chemical
# 13596  pancreatic_fibrosis pep_up populace not to go_...        chemical
# 13597  fibrocystic_disease_of_the_pancreas urge popul...        chemical
# 13598  Cf root_on world non to have tolerant of trans...        chemical
#
#                    product-category                                 hazard  \
# 0      meat, egg and dairy products                 listeria monocytogenes
# 1      meat, egg and dairy products                           listeria spp
# 2      meat, egg and dairy products                 listeria monocytogenes
# 3      meat, egg and dairy products                       plastic fragment
# 4      meat, egg and dairy products                       plastic fragment
# ...                             ...                                    ...
# 13594    other food product / mixed  unauthorised substance ethylene oxide
# 13595    other food product / mixed  unauthorised substance ethylene oxide
# 13596    other food product / mixed  unauthorised substance ethylene oxide
# 13597    other food product / mixed  unauthorised substance ethylene oxide
# 13598    other food product / mixed  unauthorised substance ethylene oxide
#
#                            product
# 0                   smoked sausage
# 1                          sausage
# 2                       ham slices
# 3      thermal processed pork meat
# 4                   chicken breast
# ...                            ...
# 13594                ramen noodles
# 13595                ramen noodles
# 13596                ramen noodles
# 13597                ramen noodles
# 13598                ramen noodles
#
# [13599 rows x 10 columns]

# %%
print_column(balanced_4, 'product-category',22)
# Out:
# Column "product-category" (n = 22):
#
#   meat, egg and dairy products:                       3592
#   fruits and vegetables:                              1675
#   cereals and bakery products:                        1261
#   prepared dishes and snacks:                         1059
#   seafood:                                             774
#   alcoholic beverages:                                 724
#   soups, broths, sauces and condiments:                675
#   nuts, nut products and seeds:                        599
#   herbs and spices:                                    580
#   non-alcoholic beverages:                             533
#   cocoa and cocoa preparations, coffee and tea:        496
#   dietetic foods, food supplements, fortified foods:   477
#   confectionery:                                       454
#   ices and desserts:                                   314
#   other food product / mixed:                          237
#   food contact materials:                              177
#   fats and oils:                                       158
#   sugars and syrups:                                    87
#   pet feed:                                             79
#   honey and royal jelly:                                76
#   feed materials:                                       55
#   food additives and flavourings:                       50

# %%
print_column(balanced_4, 'product',1500)
# Out:
# Column "product" (n = 1022):
#
#   chicken:                                             725
#   cheese:                                              688
#   beef:                                                556
#   chocolate:                                           485
#   milk:                                                345
#   sauce:                                               304
#   sausage:                                             288
#   nuts:                                                272
#   ice cream:                                           225
#   rice:                                                219
#   chicken based products:                              199
#   beef meat:                                           190
#   pork meat:                                           173
#   plastics:                                            165
#   cakes:                                               144
#   bars:                                                140
#   bread:                                               140
#   cereal:                                              137
#   ham:                                                 134
#   food supplement:                                     127
#   tea:                                                 122
#   chilli:                                              114
#   eggs:                                                108
#   prepared dish:                                       104
#   chocolates:                                          102
#   sesame:                                               98
#   poultry:                                              98
#   rolls:                                                98
#   ready to eat - cook meals:                            96
#   soup:                                                 94
#   sugar:                                                93
#   beer:                                                 88
#   salads:                                               88
#   mushrooms:                                            87
#   cookies:                                              86
#   raw milk:                                             85
#   beans:                                                85
#   noodle:                                               79
#   pet feed:                                             79
#   crackers:                                             78
#   seasoning:                                            78
#   honey:                                                76
#   pesto:                                                74
#   fresh pork:                                           72
#   beverage:                                             70
#   thermal processed pork meat:                          70
#   spinach:                                              70
#   cereals:                                              70
#   dietary supplement:                                   69
#   flour:                                                67
#   ground beef:                                          66
#   apricot kernels:                                      65
#   pasta:                                                65
#   spread:                                               64
#   oysters:                                              64
#   peppers:                                              62
#   peanuts:                                              60
#   turkey:                                               59
#   infant formula:                                       59
#   biscuits:                                             59
#   salmon:                                               58
#   chocolate bars:                                       57
#   curry:                                                57
#   peas:                                                 55
#   noodles:                                              55
#   frozen beef:                                          53
#   pastry:                                               53
#   candies:                                              52
#   raw beef meat:                                        52
#   sprouts:                                              50
#   fish products:                                        50
#   tortilla:                                             50
#   vegetables:                                           49
#   dark chocolates:                                      49
#   dates:                                                49
#   spring rolls:                                         48
#   sunflower seed:                                       48
#   sauces:                                               48
#   sandwiches:                                           48
#   millet:                                               47
#   beef products:                                        46
#   Fishes not identified:                                46
#   other dairy products:                                 46
#   baby food:                                            46
#   desserts:                                             45
#   pork sausage:                                         45
#   yoghurt:                                              45
#   basil:                                                45
#   chilled chicken:                                      45
#   jellies:                                              45
#   seafood:                                              44
#   thermal processed beef meat:                          44
#   raisins:                                              43
#   rice crackers:                                        43
#   feed materials:                                       43
#   broccoli:                                             42
#   frozen poultry:                                       42
#   radish:                                               42
#   cod:                                                  42
#   other not classified meat products:                   42
#   poultry meat:                                         42
#   salt:                                                 42
#   salami:                                               41
#   chicken breast:                                       40
#   breakfast cereals:                                    40
#   protein bar:                                          40
#   bottled water:                                        39
#   palm oil:                                             39
#   veal:                                                 39
#   potatoes:                                             38
#   chocolate products:                                   38
#   other types of meat:                                  38
#   dumplings:                                            37
#   almonds:                                              37
#   corn:                                                 37
#   raw milk cheese:                                      36
#   bakery products:                                      36
#   shrimps:                                              36
#   meat preparations:                                    36
#   prawns:                                               35
#   clams:                                                35
#   pistachio nuts:                                       35
#   lasagne:                                              35
#   olive oil:                                            34
#   butter:                                               34
#   cooked chicken:                                       34
#   tuna:                                                 32
#   pastry products:                                      32
#   spice mix:                                            32
#   apricots:                                             31
#   chilled pork:                                         31
#   tofu:                                                 31
#   green bean:                                           31
#   potato chips:                                         31
#   rum:                                                  31
#   lobster:                                              30
#   fruit juice:                                          30
#   chicken preparations:                                 30
#   goat cheese:                                          30
#   cider:                                                30
#   coconut oil:                                          30
#   pizza:                                                30
#   snack mix:                                            29
#   colours:                                              29
#   chicken meat products:                                29
#   jam:                                                  28
#   tahini:                                               28
#   dried beef meat:                                      28
#   protein bars:                                         28
#   apples:                                               28
#   Precooked cooked pork meat products:                  27
#   sesame seeds:                                         27
#   onions:                                               26
#   turkey and turkey preparations:                       26
#   buns:                                                 25
#   water for human consumption:                          25
#   frozen chicken:                                       25
#   sweets:                                               25
#   coconuts:                                             25
#   sausage products:                                     25
#   soft cheese:                                          25
#   confectionery:                                        25
#   pig meat - pork:                                      25
#   prepared dishes:                                      25
#   mozzarella:                                           25
#   mineral water:                                        25
#   seasoned chicken:                                     24
#   broths:                                               24
#   ice sticks:                                           24
#   lime:                                                 24
#   melons:                                               24
#   muffins:                                              24
#   mustard:                                              24
#   nut mix:                                              24
#   bamboo:                                               24
#   other water-based drinks:                             24
#   parmesan cheese:                                      24
#   alcoholic beverages:                                  24
#   whole chicken:                                        24
#   wine:                                                 24
#   cbd products:                                         24
#   pork shoulder:                                        24
#   smoothie:                                             24
#   chilled beef:                                         24
#   filled chocolate:                                     24
#   grated cheese:                                        24
#   cod fillets:                                          24
#   egg products:                                         24
#   gouda:                                                24
#   cereal bars:                                          24
#   cherries:                                             24
#   vacuum packed beef:                                   24
#   dried apricots:                                       24
#   fresh mushrooms:                                      23
#   chickpeas:                                            23
#   wafers:                                               23
#   mussels:                                              22
#   cow milk cheese:                                      22
#   natural honey:                                        22
#   precooked cooked beef meat products:                  21
#   dressing:                                             20
#   chicken broth:                                        20
#   plums:                                                20
#   walnuts:                                              20
#   milk chocolates:                                      20
#   bitter apricot kernels:                               20
#   hot dogs:                                             20
#   fruit mix:                                            20
#   Not classified pork meat:                             20
#   sliced ham:                                           20
#   ginger powder:                                        20
#   wheat:                                                19
#   tortilla chips:                                       19
#   vitamins:                                             19
#   bean paste:                                           19
#   pears:                                                19
#   spring water:                                         19
#   sultanas:                                             19
#   tomato sauce:                                         19
#   oregano:                                              19
#   drink powder:                                         19
#   organic dates:                                        19
#   pancakes:                                             19
#   other food product / mixed:                           19
#   dried figs:                                           19
#   pudding:                                              19
#   squid:                                                19
#   chilli peppers:                                       19
#   spice mixture:                                        19
#   toffee:                                               19
#   seeds mix:                                            19
#   flaxseed:                                             19
#   minced beef:                                          19
#   lentils:                                              19
#   veal meat:                                            19
#   cheese spread:                                        19
#   hazelnuts:                                            19
#   fresh beef:                                           19
#   hard cheese:                                          19
#   grated coconut:                                       19
#   vegetable preparation:                                19
#   soups:                                                19
#   chocolate spread:                                     18
#   noodle soup:                                          18
#   goat milk:                                            18
#   spices:                                               18
#   black pepper:                                         18
#   mozzarella cheese:                                    18
#   green pesto:                                          18
#   dietetic foods, food supplements, fortified foods:    18
#   bean sprouts:                                         18
#   fruit salad:                                          18
#   coconut sugar:                                        18
#   clams (canned):                                       18
#   vegetable samosas:                                    18
#   organic coconut oil:                                  18
#   poppy:                                                18
#   wraps:                                                17
#   cooked sausages:                                      17
#   chorizo:                                              17
#   pork preparation:                                     17
#   pasta products:                                       17
#   table water:                                          17
#   apple juice:                                          17
#   chocolate wafers:                                     17
#   duck:                                                 17
#   protein powder:                                       16
#   lamb:                                                 16
#   blackcurrant drink concentrate:                       16
#   blue cheese:                                          16
#   prepared salads:                                      16
#   snacks (various):                                     16
#   muesli:                                               15
#   coffee beans:                                         15
#   liquorice:                                            15
#   cheesy spirals:                                       14
#   milk products:                                        14
#   dried fruits:                                         14
#   raspberries:                                          14
#   chilled chicken parts:                                14
#   sesame paste:                                         14
#   boneless beef:                                        14
#   whey protein:                                         14
#   frozen vegetables:                                    14
#   brown beans:                                          14
#   frozen beef patties:                                  13
#   parsley:                                              13
#   beef trimmings:                                       13
#   beef tongue:                                          13
#   coconut milk:                                         13
#   frozen pizza:                                         13
#   basil pesto sauce:                                    13
#   oats:                                                 13
#   Catfishes (freshwater):                               13
#   white bread flour:                                    13
#   syrup:                                                13
#   pork shoulder - fresh:                                12
#   dried garlic:                                         12
#   dried sausage:                                        12
#   dried pork sausages:                                  12
#   dried lilies:                                         12
#   dried herb powder ashwagandha (withania somnifera):   12
#   dried fruit in jars:                                  12
#   dried strawberries:                                   12
#   spaghetti sauce:                                      12
#   dried elder berries:                                  12
#   sparkling beverages:                                  12
#   dried beans:                                          12
#   spice marinade:                                       12
#   dipping sauce:                                        12
#   dried shitake mushrooms (lentinula edodes):           12
#   soya product:                                         12
#   spicy sauce:                                          12
#   dry ham:                                              12
#   soya and products therefor:                           12
#   edam cheese:                                          12
#   soy yoghurt:                                          12
#   egg salad with ham:                                   12
#   eggplants:                                            12
#   soy sauce:                                            12
#   eggs and egg products:                                12
#   fermented milk product:                               12
#   soy bean paste:                                       12
#   fish sauce:                                           12
#   flavoured fresh and creamy cheese spread:             12
#   dip-sauce:                                            12
#   spicy tofu:                                           12
#   soups, broths, sauces and condiments:                 12
#   cooked chicken skewer:                                12
#   tea bags:                                             12
#   chocolate spread with hazelnuts:                      12
#   tasty trio condiment selection:                       12
#   tarragon:                                             12
#   tapioca chips:                                        12
#   tallegio (cheese):                                    12
#   cinnamon:                                             12
#   taco sauce:                                           12
#   cocktail sausage rolls:                               12
#   sweet nut snack:                                      12
#   sunflower oil:                                        12
#   structured/textured fish meat products or fish paste:   12
#   starch:                                               12
#   spicy tomato sauce:                                   12
#   squids:                                               12
#   cottage pie:                                          12
#   sprinkle mix:                                         12
#   cranberry jam:                                        12
#   cranberry juice:                                      12
#   crepe mix:                                            12
#   crushed red pepper:                                   12
#   curd cheese:                                          12
#   cured loin:                                           12
#   cured smoked ham:                                     12
#   cuttlefish:                                           12
#   spinach leaves:                                       12
#   flavoured soft drink:                                 12
#   flounders, halibuts, soles:                           12
#   chocolate mousse:                                     12
#   frozen pork trimmings:                                12
#   frozen poultry meat:                                  12
#   frozen poultry preparations:                          12
#   frozen prepared dish of chicken tikka masala with pilau rice:   12
#   frozen sausage rolls:                                 12
#   frozen sausages:                                      12
#   frozen seafood:                                       12
#   frozen seasoned potato wedges:                        12
#   frozen sliced coconut:                                12
#   frozen spicy chicken wings:                           12
#   frozen spinach:                                       12
#   frozen spring rolls:                                  12
#   frozen strawberry:                                    12
#   shrimp snacks:                                        12
#   frozen vegetarian cutlet:                             12
#   sheep milk cheese:                                    12
#   fruit juice smoothie:                                 12
#   sheep cheese:                                         12
#   shark:                                                12
#   fruit salad with cantaloupe:                          12
#   garlic pickle:                                        12
#   garlic sausage:                                       12
#   sesame seed oil:                                      12
#   ginger slices:                                        12
#   gingerbread:                                          12
#   gnocchi:                                              12
#   sesame oil:                                           12
#   goat cheese made from raw milk:                       12
#   frozen potatoes:                                      12
#   frozen pork ribs:                                     12
#   soft ripened cheese:                                  12
#   frozen pork meat:                                     12
#   french beans / green beans:                           12
#   fresh broccoli:                                       12
#   fresh dough:                                          12
#   fresh goat cheese:                                    12
#   fresh lychees:                                        12
#   soft cheese (creams):                                 12
#   fresh pork leg:                                       12
#   fresh pork loin:                                      12
#   fresh poultry and poultry prepations:                 12
#   snack mixture:                                        12
#   frozen beef lasagne:                                  12
#   frozen berries mix:                                   12
#   frozen bourbon ribs:                                  12
#   frozen breaded turkey:                                12
#   frozen burger buns:                                   12
#   frozen chicken strips with tendons:                   12
#   frozen cod fillets:                                   12
#   frozen cooked lobster meat:                           12
#   frozen diced chicken roast:                           12
#   frozen fish burgers:                                  12
#   frozen fish fillets:                                  12
#   frozen fish products:                                 12
#   frozen fried rice:                                    12
#   frozen grated coconut:                                12
#   frozen green beans:                                   12
#   frozen leek:                                          12
#   frozen peppers:                                       12
#   chocolate spelt balls:                                12
#   chocolate mini muffins:                               12
#   sesame confection:                                    12
#   beef tallow:                                          12
#   vegetable crispbakes:                                 12
#   vegetable cheese:                                     12
#   vegetable burger:                                     12
#   beetroots:                                            12
#   vegetable broth:                                      12
#   beverage base of non-fruit origin, liquid:            12
#   bilberry extract used in a food supplement:           12
#   biscuit mix:                                          12
#   black caviar:                                         12
#   veal meat and offals:                                 12
#   varnishes and coatings:                               12
#   various vegetable preparations:                       12
#   blue poppy seeds:                                     12
#   boletus mushrooms, stems and pieces:                  12
#   bolognese sauce:                                      12
#   various snacks:                                       12
#   various ready-to-eat meat products:                   12
#   bovine fat:                                           12
#   various poultry meat:                                 12
#   breakfast cereals and products therefor:              12
#   breakfast cereals for babies:                         12
#   brioche:                                              12
#   broccoli mix:                                         12
#   various fish products:                                12
#   brown mushrooms:                                      12
#   brussel sprouts:                                      12
#   buffalo milk mozzarella cheese:                       12
#   beef tenderloin cuts:                                 12
#   beef stewed:                                          12
#   chocolate flavoured cereals:                          12
#   beef burrito:                                         12
#   yellow peas:                                          12
#   white mustard seeds:                                  12
#   Torpedo-shaped catfishes (generic):                   12
#   adobo seasoning:                                      12
#   after dinner mints:                                   12
#   allspice:                                             12
#   almond kernels:                                       12
#   amaranth:                                             12
#   anchovy paste:                                        12
#   animal by-products:                                   12
#   appetizers:                                           12
#   apple cake:                                           12
#   whisky:                                               12
#   asparagus:                                            12
#   assortment of filled chocolates:                      12
#   wheat snack:                                          12
#   baby food pouches:                                    12
#   baby foods:                                           12
#   balsamic:                                             12
#   waxberry:                                             12
#   bamboo shoots:                                        12
#   bananas:                                              12
#   watermelons:                                          12
#   water for infants:                                    12
#   batter mix:                                           12
#   vinegar:                                              12
#   vegetable snack:                                      12
#   various chilled or frozen pork products:              12
#   cabbage:                                              12
#   canned artichoke hearts:                              12
#   canned crab meat in brine:                            12
#   chicken drumsticks:                                   12
#   chicken fillets:                                      12
#   turbot flatfish (psetta maxima):                      12
#   chicken products - frozen:                            12
#   chicken slices:                                       12
#   chicken steak without bone:                           12
#   tuna salad:                                           12
#   chilled beef preparations:                            12
#   chilled bengali cod curry:                            12
#   chilled boneless pork meat:                           12
#   tortilla products:                                    12
#   tortilla chips cheese:                                12
#   chilled chicken thighs:                               12
#   chilled chicken wings:                                12
#   chilled dumplings with meat:                          12
#   chilled lasagne:                                      12
#   chilled pork ribs:                                    12
#   chilled ready to eat salad and side dishes:           12
#   chilled smoked ham:                                   12
#   chilled vacuum packed beef:                           12
#   chilli oil:                                           12
#   chilli pickle:                                        12
#   thyme:                                                12
#   chocolate and strawberry flavoured cyclone milk:      12
#   chocolate dessert:                                    12
#   chocolate easter eggs with filling:                   12
#   chocolate eggs:                                       12
#   turnip leaves in sunflower seed oil:                  12
#   turnips:                                              12
#   unpasteurised cheese:                                 12
#   vanilla drink:                                        12
#   canned fish products:                                 12
#   canned meat stew:                                     12
#   canned spinach:                                       12
#   cantaloupe (fresh):                                   12
#   carbonated  water:                                    12
#   carbonated/sparkling water:                           12
#   carcasses of veal:                                    12
#   cardamom seeds:                                       12
#   cardamon seeds:                                       12
#   carps, barbels and other cyprinids:                   12
#   cattle from which the milk was used to produce raw milk cheese:   12
#   vanilla powder:                                       12
#   cereal bars with chocolate:                           12
#   unsalted organic crunchy peanut butter:               12
#   vacuum packed sliced ham:                             12
#   cereals and bakery products:                          12
#   cheddar cheese:                                       12
#   vacuum packed pork ear roll:                          12
#   cheese (taleggio capriolo):                           12
#   cheese - made from raw milk:                          12
#   cheese - melted:                                      12
#   cheese burgers:                                       12
#   cheese flavoured snacks:                              12
#   cheese sausages:                                      12
#   cheese tortilla:                                      12
#   cheese tray:                                          12
#   goat meat:                                            12
#   flavoured drinks:                                     12
#   meat loaf:                                            12
#   preserved red bean curd:                              12
#   ready to eat meat product:                            12
#   octopus:                                              12
#   rice flour:                                           12
#   multi vitamin food supplement:                        12
#   saint marcelin cheese:                                12
#   ready cooked sliced chicken tikka breast:             12
#   roasted coffee:                                       12
#   mung bean sprouts:                                    12
#   jerky products:                                       12
#   pasteurized cow milk cheese:                          12
#   roasted nuts:                                         12
#   parsnip:                                              12
#   protein supplements:                                  12
#   parmesan cheese grated:                               12
#   sandwich filling:                                     12
#   instant drink/drinking powder:                        12
#   peppermint:                                           12
#   pickled figs, cherries, pears and walnuts:            12
#   instant cereal:                                       12
#   hot chilli and hot chilli products:                   12
#   pickled cucumber:                                     12
#   pickled beetroot:                                     12
#   prepared dish containing prawns:                      12
#   massala spice mixture:                                12
#   seafood cocktail:                                     12
#   scones:                                               12
#   organic coconut flour:                                12
#   nuts, nut products and seeds:                         12
#   pesto sauce (pesto verde):                            12
#   prepared dish with chicken:                           12
#   prepared dishes and snacks:                           12
#   golden enoki mushrooms:                               12
#   indian curry:                                         12
#   sauerkraut meal:                                      12
#   raw pork meat and raw pork meat preparations:         12
#   rice cereal for children:                             12
#   orange peppers:                                       12
#   puffed rice:                                          12
#   red pesto:                                            12
#   orange sugar paste:                                   12
#   margarine:                                            12
#   raw milk goat's cheese:                               12
#   long grain rice:                                      12
#   organic chilled hummus:                               12
#   loose smoked whole chickens:                          12
#   luncheon meat:                                        12
#   lupin seeds:                                          12
#   organic chlorella powder:                             12
#   red chilli:                                           12
#   raw beef meat and raw beef meat preparations:         12
#   raw cow's milk cheese:                                12
#   nougat:                                               12
#   organic tea:                                          12
#   salami sausage:                                       12
#   liquid food supplement:                               12
#   ramen noodles:                                        12
#   lemons:                                               12
#   paprika:                                              12
#   nacho chips:                                          12
#   rice balls:                                           12
#   salted radish:                                        12
#   lemon juice:                                          12
#   non-alcoholic beer:                                   12
#   salted anchovies:                                     12
#   quorn preparation:                                    12
#   lentils stew:                                         12
#   pâté:                                                 12
#   mechanically separated chicken meat:                  12
#   refreshments:                                         12
#   oyster sauce:                                         12
#   limes:                                                12
#   milk drink:                                           12
#   meat samosas, vegetable samosas, chicken samosas and meat spring rolls:   12
#   horses:                                               12
#   seed mixe:                                            12
#   halloumi cheese:                                      12
#   mixed salad:                                          12
#   nut and raisin mix:                                   12
#   nut-almond mixture:                                   12
#   ground hot pepper:                                    12
#   ground black pepper:                                  12
#   nut mixture:                                          12
#   porcine lard:                                         12
#   ground almonds:                                       12
#   rice sticks:                                          12
#   grilled seasoned chicken plate:                       12
#   green tea:                                            12
#   green raisins:                                        12
#   green pesto basil sauce:                              12
#   red chili:                                            12
#   seasonings:                                           12
#   green basil pesto:                                    12
#   mineral waters:                                       12
#   mint chocolate:                                       12
#   pork carcass(es):                                     12
#   semi-hard cheeses:                                    12
#   pork fillets:                                         12
#   grated cheese mixture:                                12
#   nut bars:                                             12
#   pork loins - frozen:                                  12
#   grapes:                                               12
#   granola:                                              12
#   gouda cheese:                                         12
#   semolina and products therefor:                       12
#   mixed nuts:                                           12
#   plum bread &amp; butter pudding:                      12
#   nutmeg:                                               12
#   ham slices:                                           12
#   herbal premix:                                        12
#   nutrition shake:                                      12
#   millet porridge:                                      12
#   pine nuts:                                            12
#   pickled radish:                                       12
#   ricotta and spinach tortelloni pasta:                 12
#   mixed spices:                                         12
#   herbal tea:                                           12
#   rice vermicelli:                                      12
#   herbs:                                                12
#   meal replacement:                                     12
#   high protein bars:                                    12
#   moussaka:                                             12
#   honeycomb:                                            12
#   pickled gherkins in glass jar:                        12
#   prebaked apple pies:                                  12
#   raw milk cheese reblochon:                            12
#   minced beef meat:                                     12
#   powder seasoning:                                     12
#   seasoning sauce:                                      12
#   chillies:                                             11
#   pumpkin seeds:                                        11
#   potato salad:                                         11
#   pasteurized milk:                                     11
#   various chicken meat products:                        11
#   bovine meat and offal:                                11
#   mashed chickpeas (hummus):                            11
#   alfalfa sprouts:                                      11
#   smoked sausage:                                       11
#   coconut juice:                                        11
#   chicken noodle soup:                                  11
#   almond products:                                      11
#   macadamia nuts:                                       11
#   herring:                                              10
#   chilli sauce:                                         10
#   blueberries:                                          10
#   mitragyna speciosa (kratom):                          10
#   bread and products therefor:                          10
#   algae:                                                10
#   milk chocolate covered raisins:                       10
#   hemp tea:                                             10
#   all purpose seasoning:                                10
#   baby spinach:                                         10
#   hemp oil:                                             10
#   brazil nuts:                                          10
#   pasta salad:                                          10
#   mackerel:                                              9
#   rice snack:                                            9
#   carbonated beverage:                                   9
#   chia seeds:                                            9
#   cbd oil:                                               9
#   coriander:                                             9
#   snack crackers:                                        9
#   cashew:                                                9
#   kale:                                                  9
#   feta cheese:                                           9
#   cheese products:                                       8
#   mayonnaise:                                            8
#   olives:                                                8
#   cupcakes:                                              8
#   cream cheese:                                          8
#   meat and meat products (other than poultry):           8
#   instant noodles:                                       8
#   fresh vegetables:                                      8
#   minced pork:                                           8
#   frozen burgers:                                        8
#   dried mushrooms:                                       8
#   burrito (ready to eat):                                8
#   dried plums:                                           8
#   ginseng powder:                                        8
#   Pangas catfishes (generic):                            8
#   frozen whole fish:                                     8
#   almond milk:                                           8
#   frozen peas:                                           8
#   boar:                                                  8
#   probiotic food supplement:                             8
#   sweeteners:                                            8
#   frozen ready to cook chicken:                          8
#   tiger nuts:                                            7
#   chilli powder:                                         7
#   chicken and chicken preparations:                      7
#   tilapia:                                               7
#   chocolate and hazelnut spread:                         7
#   chilli paste:                                          7
#   chicken meat meal:                                     7
#   chilled salads:                                        7
#   chilled pork sausages:                                 7
#   turkey based products:                                 7
#   rice noodles:                                          7
#   tomatoes:                                              7
#   rice meal:                                             7
#   nut and fruit mixture:                                 7
#   rice flakes:                                           7
#   rice cakes:                                            7
#   non-alcoholic beverages:                               7
#   turkey sandwich:                                       7
#   chicken pie:                                           7
#   goji berries:                                          7
#   brie cheese:                                           7
#   vacuum packed marinated pork:                          7
#   white beans:                                           7
#   vitamins supplement:                                   7
#   bean snack:                                            7
#   vodka:                                                 7
#   waffles:                                               7
#   barbecue sauce:                                        7
#   pickled ginger:                                        7
#   pickled grape leaves:                                  7
#   baking mix:                                            7
#   weight loss coffee:                                    7
#   baguettes:                                             7
#   pickled peppers:                                       7
#   assorted bread roll selection:                         7
#   white cheese:                                          7
#   pecorino cheese:                                       7
#   angus beef:                                            7
#   anchovies in oil:                                      7
#   white chocolate:                                       7
#   almond powder:                                         7
#   pork and beef sausages:                                7
#   white lasagna sauce:                                   7
#   pork belly:                                            7
#   Veggie Burger:                                         7
#   white mould cheese:                                    7
#   Groupers (generic):                                    7
#   potato croquettes:                                     7
#   Dried pork meat:                                       7
#   pepperoni:                                             7
#   pretzel stick:                                         7
#   nuts and nuts products:                                7
#   brown rice:                                            7
#   nuts mix:                                              7
#   cereal drink:                                          7
#   cauliflower:                                           7
#   canned mussels:                                        7
#   canned chicken:                                        7
#   canned black beans:                                    7
#   other fruit and vegetable juice products:              7
#   various beef products:                                 7
#   camembert:                                             7
#   ravioli:                                               7
#   burrata:                                               7
#   brownies:                                              7
#   various meat products:                                 7
#   pear juice:                                            7
#   mix of nuts:                                           7
#   brewer's yeast:                                        7
#   papaya:                                                7
#   bread mix:                                             7
#   bread crumb:                                           7
#   various prepared dishes:                               7
#   bloody mary beverage mix:                              7
#   prosciutto:                                            7
#   vegetable based products:                              7
#   pastry tartlets:                                       7
#   pea shoots:                                            7
#   peaches:                                               7
#   chocolate and products therefor:                       7
#   yogurt raisins:                                        7
#   testosterone booster:                                  7
#   hot dog sausages:                                      7
#   frozen boneless beef:                                  7
#   dried shrimp noodles:                                  7
#   hot chicken wings:                                     7
#   dried pangash:                                         7
#   lokoum:                                                7
#   frozen broccoli:                                       7
#   dried fruits with chocolate:                           7
#   soybean:                                               7
#   dried fruit mix:                                       7
#   seafood products:                                      7
#   dried chilli peppers:                                  7
#   dried brown beans:                                     7
#   frozen hamburgers:                                     7
#   dried apples:                                          7
#   dried anchovies:                                       7
#   frozen marinated beef:                                 7
#   spicy chicken skewers:                                 7
#   donuts:                                                7
#   mango:                                                 7
#   frozen pancakes:                                       7
#   fresh apples:                                          7
#   diced beef:                                            7
#   marzipan:                                              7
#   frozen pie:                                            7
#   deboned chicken thighs:                                7
#   masala spice mix:                                      7
#   sliced bread:                                          7
#   drinking chocolate powder:                             7
#   dry sausage:                                           7
#   frozen pork preparations:                              7
#   frozen beef trimmings:                                 7
#   foie gras:                                             7
#   sorbets:                                               7
#   sandwich spread:                                       7
#   flavours:                                              7
#   fresh beef meat:                                       7
#   flavoured whey protein preparations:                   7
#   juice drink:                                           7
#   flavoured potato chips:                                7
#   fresh cut vegetables:                                  7
#   instant coffee:                                        7
#   fresh parsley:                                         7
#   pork pie:                                              7
#   fish roe:                                              7
#   ketchup:                                               7
#   ices and desserts:                                     7
#   fermented beef meat:                                   7
#   iced tea:                                              7
#   soy products:                                          7
#   fats and oils:                                         7
#   fajita meal:                                           7
#   fresh processed beef meat products:                    7
#   lemonade (lemon soda):                                 7
#   frozen beef products:                                  7
#   frozen beef tongue:                                    7
#   lettuce:                                               7
#   soya drink:                                            7
#   chocolate chips:                                       7
#   dark chocolate coated almonds:                         7
#   seasoning mix:                                         7
#   curry sauces:                                          7
#   milk and milk products:                                7
#   seaweed preparations:                                  7
#   meat-salad:                                            7
#   cooked meat products:                                  7
#   curry paste:                                           7
#   fruit bars:                                            7
#   confectionery for decoration:                          7
#   seeds mixture:                                         7
#   concentrated apples:                                   7
#   fruit pies:                                            7
#   sugar confectionary:                                   7
#   cola drink:                                            7
#   fruit punch:                                           7
#   sushi:                                                 7
#   swiss rolls:                                           7
#   table water and soda water:                            7
#   cottage cheese:                                        7
#   roasted and caramelized peanuts:                       7
#   fruit snacks:                                          7
#   fruits and vegetables:                                 7
#   milk powder:                                           7
#   semi-soft cheese:                                      7
#   gluten free bread:                                     7
#   chocolate truffles:                                    7
#   tea drink:                                             7
#   minced chicken:                                        7
#   chocolate flavoured meringues:                         7
#   chocolate drinks:                                      7
#   chocolate drink powder:                                7
#   chocolate confectionery:                               7
#   golden raisins/sultanas:                               7
#   sprinkles:                                             7
#   frozen vegetables mix:                                 7
#   crisp cheese snack:                                    7
#   frozen raw ground beef:                                7
#   sport drink:                                           7
#   halva:                                                 7
#   sichuan pepper:                                        7
#   crustaceans and products thereof:                      7
#   crisps:                                                7
#   crispbread:                                            7
#   cream chocolate pie:                                   7
#   ground turmeric:                                       7
#   french toast:                                          7
#   crabs:                                                 7
#   meat, egg and dairy products:                          7
#   courgettes:                                            7
#   ground beef meat:                                      6
#   guacamole:                                             6
#   frozen marinated chicken:                              6
#   gorgonzola cheese:                                     6
#   fresh cheese:                                          6
#   pop corn:                                              6
#   prawn crackers:                                        6
#   hemp protein powder:                                   6
#   pomegranate:                                           6
#   poultry meat and poultry meat products:                6
#   soft drinks:                                           6
#   grissini breadsticks:                                  6
#   pretzels:                                              6
#   vegetable mix:                                         6
#   garlic powder:                                         6
#   vegetable ready to eat meals:                          6
#   frozen ready to eat products:                          6
#   baklava:                                               6
#   soda drink:                                            6
#   prepacked salad:                                       6
#   frozen chicken wings:                                  6
#   frozen poultry products:                               6
#   gravy granules:                                        6
#   frozen lobster:                                        6
#   frozen hash browns:                                    6
#   scallops:                                              6
#   bagels:                                                6
#   bean sauce:                                            6
#   frozen dumplings with pork:                            6
#   gravy mix:                                             6
#   horseradish in jars:                                   6
#   paella:                                                6
#   sardines:                                              6
#   cumin powder:                                          6
#   cous cous:                                             6
#   spreads:                                               6
#   tzatziki sauce:                                        6
#   meat broth:                                            6
#   croissants:                                            6
#   cultivated fungi:                                      6
#   cheese dip:                                            6
#   marshmalows:                                           6
#   ready-to-eat seafood sticks:                           6
#   cured pork meat:                                       6
#   custard:                                               6
#   spirits:                                               6
#   orange juice:                                          6
#   various bakery products:                               6
#   chicken dippers:                                       6
#   cooking sauce:                                         6
#   meatloaf:                                              6
#   cooked ham:                                            6
#   melon seeds:                                           6
#   stuffed pastry:                                        6
#   trouts:                                                6
#   mustard sauce:                                         6
#   coffee drink:                                          6
#   coconut milk drink:                                    6
#   tahini (sesame paste):                                 6
#   cinnamon rolls:                                        6
#   chorizo sausage:                                       6
#   mixed vegetables:                                      6
#   ricotta cheese:                                        6
#   milk proteins:                                         6
#   chocolate and chocolate products:                      6
#   dietary capsules:                                      6
#   marinated chicken meat:                                6
#   vegan sausages:                                        6
#   fish and fish products:                                6
#   egg rolls:                                             6
#   emulsifiers, stabilizers, thickeners and gelling agents:    6
#   energy and protein bars:                               6
#   energy drink:                                          6
#   fennel seeds:                                          6
#   soy milk product:                                      6
#   bottled mineral water:                                 6
#   dressing sauces:                                       6
#   protein drink:                                         6
#   protein balls:                                         6
#   juices:                                                6
#   flavoured milk:                                        6
#   pasta sauce:                                           6
#   blackberries:                                          6
#   various pasta products:                                6
#   quinoa:                                                6
#   salami sticks:                                         6
#   liquid egg white:                                      6
#   salad dressing:                                        6
#   lollipops:                                             6
#   cake decoration:                                       6
#   various cheeses:                                       6
#   dried cranberries:                                     6
#   dried coconut:                                         6
#   canned corn:                                           6
#   organic tofu:                                          6
#   maize:                                                 6
#   organic figs:                                          6
#   caramel bites:                                         6
#   raw goat milk cheese:                                  6
#   dried almonds:                                         6
#   coconut drink:                                         6

# %%
print_column(balanced_4, 'hazard',128)
# Out:
# Column "hazard" (n = 128):
#
#   listeria monocytogenes:                             1347
#   salmonella:                                         1310
#   milk and products thereof:                          1262
#   other:                                               748
#   cereals:                                             540
#   cereals containing gluten and products thereof:      510
#   nuts:                                                502
#   peanuts and products thereof:                        459
#   eggs and products thereof:                           440
#   escherichia coli:                                    434
#   plastic fragment:                                    403
#   sulphur dioxide:                                     392
#   soybeans and products thereof:                       335
#   inspection issues:                                   324
#   metal fragment:                                      323
#   sulphur dioxide and sulphites:                       299
#   chemical:                                            247
#   toxin:                                               237
#   other not classified:                                232
#   glass fragment:                                      224
#   mustard and products thereof:                        189
#   almond:                                              153
#   unauthorised substance ethylene oxide:               134
#   misdescription:                                      127
#   heavy metals:                                        107
#   virus:                                               106
#   processing:                                          104
#   incorrect labeling:                                  103
#   foreign bodies:                                       99
#   chlorine:                                             95
#   clostridium botulinum:                                89
#   moulds:                                               78
#   sesame seeds and products thereof:                    76
#   cashew:                                               74
#   misbranding:                                          72
#   bulging packaging:                                    68
#   high content of copper:                               66
#   other not classified chemical hazards:                65
#   chemical compound (unauthorised):                     62
#   packaging defect:                                     59
#   insufficient labelling/documentation:                 56
#   fish and products thereof:                            56
#   poor or insufficient controls:                        54
#   compositional deviation:                              53
#   undeclared additive:                                  53
#   incorrect use by dates:                               52
#   bacillus spp.:                                        52
#   insects:                                              51
#   altered organoleptic characteristics:                 48
#   sulfamethazine unauthorised:                          48
#   contaminant:                                          48
#   alcohol content:                                      48
#   organochlorine:                                       48
#   false marketing claims:                               47
#   nitrogen:                                             47
#   dioxins:                                              47
#   dairy products:                                       47
#   haloxyfop:                                            47
#   ochratoxin:                                           47
#   staphylococcal enterotoxin:                           47
#   vibrio spp:                                           47
#   other not classified allergen hazards:                47
#   unfit for human consumption:                          47
#   paralytic shellfish poisoning (psp) toxins:           47
#   alkaloids:                                            47
#   coconut:                                              47
#   phenylpyrazole:                                       47
#   unauthorised operator:                                47
#   amygdalin:                                            47
#   too high content of fluorinated organic chemicals:    47
#   other misbranding issues:                             47
#   tampering:                                            47
#   improper conditions:                                  46
#   rubber fragments:                                     46
#   spoilage:                                             44
#   labelling/misdescription:                             44
#   walnut:                                               41
#   unauthorised substance sildenafil:                    41
#   chemical compound (high content):                     40
#   improper packaging:                                   40
#   polycyclic aromatic hydrocarbons:                     40
#   enteroviruses:                                        39
#   pieces of wood:                                       39
#   pahs:                                                 39
#   non compliance with HACCP:                            39
#   molluscs and products thereof:                        39
#   brazil nut:                                           38
#   yeasts:                                               38
#   high content of vitamins:                             38
#   novel food:                                           38
#   abnormal smell:                                       37
#   product category/characteristics:                     37
#   sulphates/sulphites:                                  37
#   unauthorised colour sudan 4:                          37
#   allergens:                                            36
#   bone fragment:                                        35
#   staphylococcus:                                       35
#   pseudomonas spp.:                                     34
#   pecan nut:                                            32
#   mislabelled:                                          32
#   e 425 - konjac unauthorised:                          32
#   bad smell / off odor:                                 32
#   coliforms:                                            31
#   poor hygienic state:                                  31
#   listeria spp:                                         31
#   high content of cyanide:                              31
#   crustaceans and products thereof:                     30
#   stones:                                               29
#   antibiotics, vet drugs:                               29
#   too high content of tetrahydrocannabinol (THC):       29
#   norovirus:                                            29
#   pistachio nut:                                        28
#   celery and products thereof:                          28
#   unauthorised placing on the market:                   28
#   cronobacter spp:                                      28
#   damaged packaging:                                    28
#   taste disturbance:                                    28
#   microbiological contamination:                        28
#   unauthorised import:                                  27
#   pathogenic bacteria:                                  27
#   undeclared constituent:                               26
#   hazelnut:                                             26
#   specified risk material (srm):                        25
#   cyclospora:                                           25
#   other not classified hazards for foreign bodies:      24
#   patulin:                                              23
#   other not classified biological hazards:              23
#   Aflatoxin:                                            23

# %%
print_column(balanced_4, 'hazard')
# Out:
# Column "hazard" (n = 128):
#
#   listeria monocytogenes:                             1347
#   salmonella:                                         1310
#   milk and products thereof:                          1262
#   other:                                               748
#   cereals:                                             540
#   cereals containing gluten and products thereof:      510
#   nuts:                                                502
#   peanuts and products thereof:                        459
#   eggs and products thereof:                           440
#   escherichia coli:                                    434

# %%
# duplicate 
balanced_4[balanced_4['text'].duplicated()].shape[0] # TODO shall I remove them? 
balanced_4[balanced_4['text'].duplicated()]
# Out:
#       year  month  day country  \
# 573   2011      9   21      ca
# 603   2012      1   27      ca
# 691   2012      8    8      ca
# 709   2012      9   25      ca
# 714   2012      9   27      ca
# 717   2012     10    1      ca
# 1073  2014      9   12      uk
# 1107  2014     10   16      uk
# 1145  2014     12   23      uk
# 1150  2014     12   27      us
# 2730  2018      6    2      us
# 3104  2019      2    9      ca
# 3267  2019      5   24      us
# 3441  2019      9   20      ca
# 3453  2019     10    2      ca
# 3463  2019     10    4      ca
# 3479  2019     10   11      ca
# 3482  2019     10   12      ca
# 3484  2019     10   13      ca
# 3498  2019     10   19      ca
# 3499  2019     10   19      ca
# 3518  2019     10   30      ca
# 3589  2019     12   11      ca
# 4232  2021      2   19      ca
# 4269  2021      3   11      ca
# 4282  2021      3   18      hk
# 4288  2021      3   19      us
# 4290  2021      3   20      us
# 4593  2021      9   24      us
#
#                                                   title  \
# 573   Certain Gatorade brand products are being reca...
# 603   Pinnacle Foods Group LLC Issues Allergy Alert ...
# 691        Various milk may contain extraneous material
# 709   Certain TRADER JOE'S brand NUT BUTTERS may con...
# 714   Various beef products may contain E. coli O157...
# 717   Certain Nestle brand Chocolate Peanut Butter I...
# 1073  Spiceway, Rutherglen products handled and pack...
# 1107  Jumbo UK Ltd recalls its Nigeria Taste Brown B...
# 1145  Ades Limited products handled and packaged in ...
# 1150  Texas Firm Recalls Pork Products Due To Misbra...
# 2730  Supermercado Selectos Recalls Raw, Frozen Meat...
# 3104  Betty brand and Nancy's Fancy Yummy-in-the-Tum...
# 3267  In Association with ADM Milling Co., ALDI Issu...
# 3441  Parador Plus brand Bouillon Chicken Concentrat...
# 3453  Certain sandwiches and in-store made chicken s...
# 3463  Ryding-Regency Meat Packers Ltd. brand raw bee...
# 3479  Corned Beef products recalled due to Listeria ...
# 3482  Various raw beef and raw veal products recalle...
# 3484  Certain President's Choice brand Powdered Infa...
# 3498  Various raw beef and raw veal products recalle...
# 3499  MF Inc. brand fishballs recalled due to potent...
# 3518  Compliments brand Sweet Kale Blend recalled du...
# 3589  PC brand Cranberry Goat's Milk Cheese may be u...
# 4232  Valentine Eruption Cake sold by Save-On-Foods ...
# 4269  Consumption of Organic Traditions brand Dried ...
# 4282  CFS urges public not to consume seasoning from...
# 4288  Three Turkey Wrap Sandwiches Added to Mg Foods...
# 4290  Avanza Pasta, LLC Recalls Beef and Poultry Pro...
# 4593  Suntree Snack Foods, LLC. Issues Voluntary Rec...
#
#                                                    text       hazard-category  \
# 573   Notice This archive of previously issued food ...  organoleptic aspects
# 603   Notice This archive of previously issued food ...             allergens
# 691   Various milk may contain extraneous material R...        foreign bodies
# 709   Notice This archive of previously issued food ...            biological
# 714   Notice This archive of previously issued food ...            biological
# 717   Notice This archive of previously issued food ...            biological
# 1073  GSR Distributions Ltd, trading as Spiceway, Ru...                 fraud
# 1107  Risk\nJumbo UK Ltd has recalled all batches of...              chemical
# 1145  Ades Limited, 1 Eastmoor Street, Charlton, Lon...                 fraud
# 1150  WASHINGTON, December 27, 2014 – Garcia Foods, ...             allergens
# 2730  EDITOR’S NOTE: This release was updated on Jun...                 fraud
# 3104  Food Recall Warning - Betty brand and Nancy's ...          other hazard
# 3267  null In cooperation with ADM Milling Co., ALDI...            biological
# 3441  Notice This archive of previously issued food ...            biological
# 3453  Notice This archive of previously issued food ...            biological
# 3463  Service interruption Please note that due to r...            biological
# 3479  Notice This archive of previously issued food ...            biological
# 3482  Updated Food Recall Warning - Various raw beef...            biological
# 3484  Correction - Food Recall Warning - Certain Pre...            biological
# 3498  Notice This archive of previously issued food ...            biological
# 3499  Food Recall Warning - MF Inc. brand fishballs ...            biological
# 3518  Notice This archive of previously issued food ...            biological
# 3589  Food Recall Warning - PC brand Cranberry Goat'...        foreign bodies
# 4232  Food Recall Warning (Allergen) - Valentine Eru...             allergens
# 4269  Food Recall Warning - Consumption of Organic T...              chemical
# 4282  CFS urges public not to consume seasoning from...              chemical
# 4288  MG Foods of Charlotte, NC is expanding its rec...            biological
# 4290  009-2021\n\n  \n  High\n\n    Produced Without...                 fraud
# 4593  Committed to quality and out of an abundance o...        foreign bodies
#
#                           product-category  \
# 573                non-alcoholic beverages
# 603            cereals and bakery products
# 691           meat, egg and dairy products
# 709           nuts, nut products and seeds
# 714           meat, egg and dairy products
# 717                      ices and desserts
# 1073          meat, egg and dairy products
# 1107                 fruits and vegetables
# 1145                               seafood
# 1150          meat, egg and dairy products
# 2730          meat, egg and dairy products
# 3104           cereals and bakery products
# 3267           cereals and bakery products
# 3441  soups, broths, sauces and condiments
# 3453          meat, egg and dairy products
# 3463          meat, egg and dairy products
# 3479          meat, egg and dairy products
# 3482          meat, egg and dairy products
# 3484          meat, egg and dairy products
# 3498          meat, egg and dairy products
# 3499                               seafood
# 3518                 fruits and vegetables
# 3589          meat, egg and dairy products
# 4232           cereals and bakery products
# 4269                 fruits and vegetables
# 4282                      herbs and spices
# 4288            prepared dishes and snacks
# 4290  soups, broths, sauces and condiments
# 4593                         confectionery
#
#                                      hazard  \
# 573                                spoilage
# 603           soybeans and products thereof
# 691                          foreign bodies
# 709                              salmonella
# 714                        escherichia coli
# 717                              salmonella
# 1073     unauthorised placing on the market
# 1107       chemical compound (high content)
# 1145                                  other
# 1150           peanuts and products thereof
# 2730                      inspection issues
# 3104                   other not classified
# 3267                       escherichia coli
# 3441                                 yeasts
# 3453                 listeria monocytogenes
# 3463                       escherichia coli
# 3479                 listeria monocytogenes
# 3482                       escherichia coli
# 3484                        cronobacter spp
# 3498                       escherichia coli
# 3499                  clostridium botulinum
# 3518                 listeria monocytogenes
# 3589                       plastic fragment
# 4232                                 walnut
# 4269                              amygdalin
# 4282  unauthorised substance ethylene oxide
# 4288                 listeria monocytogenes
# 4290                      inspection issues
# 4593                         glass fragment
#
#                                   product
# 573                           sport drink
# 603                              pancakes
# 691                                  milk
# 709                               walnuts
# 714                         beef products
# 717                             ice cream
# 1073                chilled chicken parts
# 1107                          brown beans
# 1145                     seafood products
# 1150                              chorizo
# 2730                              poultry
# 3104                                 buns
# 3267                                flour
# 3441                        chicken broth
# 3453               chicken based products
# 3463                        beef products
# 3479  precooked cooked beef meat products
# 3482                        raw beef meat
# 3484                       infant formula
# 3498                        raw beef meat
# 3499                Fishes not identified
# 3518                                 kale
# 3589                          goat cheese
# 4232                                cakes
# 4269               bitter apricot kernels
# 4282                            seasoning
# 4288                           sandwiches
# 4290                        prepared dish
# 4593                                halva

# %% [markdown]
# ### NLP Standard Preprocess
# - Text preprocessing is essential to ensure `clean`, `consistent`, and `semantically meaningful input` for NLP models, ultimately `improving` their `performance, interpretability, and computational efficiency`.
#
# - Preprocessing Steps of the function `preprocess_dataframe_column` (Controlled by params):
#     - Lowercase Conversion: Standardizes text by converting to lowercase.
#     - Punctuation Removal: Removes all punctuation marks.
#     - Stopword Removal: Removes common words that add little meaning (e.g., "the", "is").
#     - Number Removal: Eliminates numeric tokens.
#     - Lemmatization: Converts words to their base forms (e.g., "running" → "run").
#     - Stemming (Optional): Reduces words to their root forms (e.g., "running" → "run"), used if lemmatization is disabled.

# %%
balanced_4

# %%
def nlp_preprocess_dataframe(
    df,
    column,
    lowercase=True,
    remove_punctuation=True,
    remove_stopwords=True,
    remove_numbers=True,
    lemmatization=True,
    stemming=True
):
    """
    Preprocesses a specified column of a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to preprocess.
        column (str): Name of the column to preprocess.
        lowercase (bool): Convert text to lowercase. Default is True.
        remove_punctuation (bool): Remove punctuation. Default is True.
        remove_stopwords (bool): Remove common stopwords. Default is True.
        remove_numbers (bool): Remove numeric tokens. Default is True.
        lemmatization (bool): Apply lemmatization. Default is True.
        stemming (bool): Apply stemming. Default is True.

    Returns:
        None: The function directly modifies the input DataFrame.
    """
    # Initialize tools
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    stemmer = PorterStemmer()

    def preprocess_text(text):
        if pd.isnull(text):  # Handle NaN values
            return text
        # Tokenize the text
        tokens = word_tokenize(str(text))

        # Convert to lowercase
        if lowercase:
            tokens = [token.lower() for token in tokens]

        # Remove punctuation
        if remove_punctuation:
            tokens = [token for token in tokens if token not in string.punctuation]

        # Remove stopwords
        if remove_stopwords:
            tokens = [token for token in tokens if token not in stop_words]

        # Remove numbers
        if remove_numbers:
            tokens = [token for token in tokens if not token.isdigit()]

        # Apply lemmatization
        if lemmatization:
            tokens = [lemmatizer.lemmatize(token) for token in tokens]

        # Apply stemming
        if stemming:
            tokens = [stemmer.stem(token) for token in tokens]

        # Join tokens back to a single string
        return ' '.join(tokens)

    # Apply preprocessing directly to the specified column
    df[column] = df[column].apply(preprocess_text)

# %%
# Call the function to preprocess a specific column
nlp_preprocess_dataframe(
    balanced_4,               # DataFrame
    column="title",           # Column to preprocess
    lowercase=True,           # Convert to lowercase
    remove_punctuation=True,  # Remove punctuation
    remove_stopwords=True,    # Remove stopwords
    remove_numbers=True,      # Remove numeric tokens
    lemmatization=True,       # Apply lemmatization
    stemming=True             # Apply Stemming
)

nlp_preprocess_dataframe(
    balanced_4,               # DataFrame
    column="text",            # Column to preprocess
    lowercase=True,           # Convert to lowercase
    remove_punctuation=True,  # Remove punctuation
    remove_stopwords=True,    # Remove stopwords
    remove_numbers=True,      # Remove numeric tokens
    lemmatization=True,       # Apply lemmatization
    stemming=True             # Apply stemming
)

# %%
balanced_4

# %% [markdown]
# ## Sava Data Augmented and NLP preprocessed Data

# %% [markdown]
# - We will save our data to the folder `data` in file `data_augmented__nlp_incidents_train.csv`.

# %%
# Define the folder and file path
folder_path = "data"
file_path = os.path.join(folder_path, "data_augmented__nlp_incidents_train.csv")
# Create the folder if it doesn't exist
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
# Save your data to the specified file
balanced_4.to_csv(file_path, index=False)
print(f"File saved to {file_path}")
# Out:
# File saved to data/data_augmented__nlp_incidents_train.csv
